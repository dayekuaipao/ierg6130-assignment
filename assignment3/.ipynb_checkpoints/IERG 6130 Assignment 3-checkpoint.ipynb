# %% [markdown]
# # IERG 6130 Assignment 3: Policy Gradient
#
# *2019-2020 2nd term, IERG 6130: Reinforcement Learning and Beyond. Department of Information Engineering, The Chinese University of Hong Kong. Course Instructor: Professor ZHOU Bolei. Assignment author: PENG Zhenghao.*

# %% [markdown]
# | Student Name | Student ID |
# | :----: | :----: |
# | TYPE_YOUR_NAME_HERE | TYPE_YOUR_STUDENT_ID_HERE |
#
# ------

# %% [markdown]
# Welecome to the assignment 3 of our RL course.
#
# You need to go through this self-contained notebook, which contains many TODOs in part of the cells and has special `[TODO]` signs. You need to finish all TODOs. Some of them may be easy such as uncommenting a line, some of them may be difficult such as implementing a function. You can find them by searching the `[TODO]` symbol. However, we suggest you to go through the notebook step by step, which would give you a better understanding of the content.
#
# You are encouraged to add more code on extra cells at the end of the each section to investigate the problems you think interesting. At the end of the file, we left a place for you to optionaly write comments.
#
# Please report any code bugs to us via cuhkrlcourse@googlegroups.com or via github issue. Before you submission, remember to check the submit instruction at the directory of this assignment and make sure the required contents are included in your submission.
#
# Before you get start, remember to follow the instruction at https://github.com/cuhkrlcourse/ierg6130 to setup your environment.
#
# We will cover the following knowledege in this assignment:
#
# 1. Basic policy gradient method
# 2. Policy gradient with baseline
# 3. Actor-critic framework
#
# You need to install some packages.
# 1. Install `yaml` package via `pip install pyyaml` to print training information.
# 2. Install `pandas` via `pip install pandas` to organize the learning progress.
# 3. Install `matplotlib` via `pip install matplotlib` to visualize the learning result.
# 4. Install `seaborn` via `pip install seaborn` to visualize the learning result (beautiful than matplotlib).

# %% [markdown]
# ------
#
# ## Section 1: Basic reinforcement learning pipeline
#
# (5 / 100 points)
#
# In this section, we will prepare several functions for evaulation, training RL algorithms. We will also build an `AbstractTrainer` class used as a general framework which left blanks for policy gradient methods.
#
# A essential difference of this assignment compared to the previous is that: the sampling and the optimization are splited into two phase. In each training iteration, the agent first collects a batch of samples followed by conducting the policy optimization. This modification allows us to have a clear view on the training process.

# %%
# Run this cell without modification

import time
import gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import seaborn as sns
import pandas as pd

from utils import *

# %%
# Run this cell without modification

def run(trainer_cls, config=None, reward_threshold=None):
    """Run the trainer and report progress, agnostic to the class of trainer
    :param trainer_cls: A trainer class 
    :param config: A dict
    :param reward_threshold: the reward threshold to break the training
    :return: The trained trainer and a dataframe containing learning progress
    """
    assert inspect.isclass(trainer_cls)
    if config is None:
        config = {}
    trainer = trainer_cls(config)
    config = trainer.config
    start = now = time.time()
    stats = []
    print("=== {} {} Training Start ===".format(trainer_cls.__name__, config["env_name"]))
    pretty_print({"Config": config})
    for i in range(config['max_iteration'] + 1):
        stat = trainer.train()
        stats.append(stat or {})
        if i % config['evaluate_interval'] == 0 or \
                i == config["max_iteration"]:
            reward = trainer.evaluate(config["evaluate_num_episodes"])
            stat["evaluate_reward"] = reward
            print("=== {} {} Iteration {} ===".format(
                trainer_cls.__name__, config["env_name"], i)
            )
            pretty_print({"Training Progress": stat})
            now = time.time()
        if reward_threshold is not None and reward > reward_threshold:
            print("In {} iteration, current mean episode reward {:.3f} is "
                  "greater than reward threshold {}. Congratulation! Now we "
                  "exit the training process.".format(
                i, reward, reward_threshold))
            break
    stats = pd.DataFrame(stats)
    return trainer, stats

# %%
# Solve the TODOs and remove `pass`

default_config = dict(
    env_name="CartPole-v0",
    
    max_iteration=1000,
    max_episode_length=1000,
    
    train_batch_size=1000,
    gamma=0.99,
    learning_rate=0.01,
    seed=0,
    
    evaluate_interval=10,
    evaluate_num_episodes=50
)


class AbstractTrainer:
    """This is the abstract class for value-based RL trainer. We will inherent
    the specify algorithm's trainer from this abstract class, so that we can
    reuse the codes.
    """

    def __init__(self, config=None):
        self.config = check_and_merge_config(config or {}, default_config)

        # Create the environment
        self.env_name = self.config['env_name']
        self.env = gym.make(self.env_name)
        if "ram" in self.env_name:  # Special process for Atari games
            self.env = wrap_deepmind_ram(self.env)

        # Apply the random seed
        self.seed = self.config["seed"]
        seed_everything(self.seed)
        self.env.seed(self.seed)

        assert isinstance(self.env.observation_space,
                          gym.spaces.Box), self.env.observation_space
        self.obs_dim = self.env.observation_space.shape[0]
        self.discrete_obs = True

        assert isinstance(self.env.action_space, gym.spaces.discrete.Discrete)
        self.act_dim = self.env.action_space.n

        self.iteration = 0
        self.start_time = time.time()
        self.iteration_time = self.start_time
        self.total_timesteps = 0
        self.total_episodes = 0

        # build the model
        self.build_model()

    def build_model(self):
        raise NotImplementedError()

    # ===== Helper functions =====
    def evaluate(self, num_episodes=10, render=False):
        """Evaluate the agents for num_episodes episodes."""
        return evaluate_agent(self, self.env, num_episodes, render)

    def to_tensor(self, array):
        """Preprocess the observation."""
        raise NotImplementedError()

    def compute_action(self, observation):
        """Return the action, which can feed to self.env.step immediately."""
        raise NotImplementedError()

    def compute_values(self, observation):
        raise NotImplementedError()

    def compute_log_probs(self, observation):
        raise NotImplementedError()

    # ===== Training-related functions =====
    def collect_samples(self):
        """Here we define the pipeline to collect sample even though
        any specify functions are not implemented yet.
        """
        iter_timesteps = 0
        iter_episodes = 0
        episode_lens = []
        episode_rewards = []
        episode_obs_list = []
        episode_act_list = []
        episode_reward_list = []
        while iter_timesteps <= self.config["train_batch_size"]:
            obs_list, act_list, reward_list = [], [], []
            obs = self.env.reset()
            steps = 0
            episode_reward = 0
            while True:
                act = self.compute_action(obs)
                next_obs, reward, done, _ = self.env.step(act)

                obs_list.append(obs)
                act_list.append(act)
                reward_list.append(reward)

                obs = next_obs.copy()
                steps += 1
                episode_reward += reward
                if done or steps > self.config["max_episode_length"]:
                    break
            iter_timesteps += steps
            iter_episodes += 1
            episode_rewards.append(episode_reward)
            episode_lens.append(steps)
            episode_obs_list.append(np.array(obs_list, dtype=np.float32))
            episode_act_list.append(np.array(act_list, dtype=np.float32))
            episode_reward_list.append(np.array(reward_list, dtype=np.float32))
        
        # [TODO] Uncomment everything below and understand the data structure:
        # The return `samples` is a dict that contains several fields.
        # Each field (key-value pair) contains a list.
        # Each element in list is a list represent the data in one trajectory (episode).
        # Each episode list contains the data of that field of all time steps in that episode.
        # The return `sample_info` is a dict contains logging item name and its value.
        
        samples = {
            "obs": episode_obs_list,
            "act": episode_act_list,
            "reward": episode_reward_list
        }
        
        #pass
        
        sample_info = {
            "iter_timesteps": iter_timesteps,
            "iter_episodes": iter_episodes,
            "performance": np.mean(episode_rewards),  # help drawing figures
            "training_episode_length": {
                "mean": float(np.mean(episode_lens)),
                "max": float(np.max(episode_lens)),
                "min": float(np.min(episode_lens))
            },
            "training_episode_reward": {
                "mean": float(np.mean(episode_rewards)),
                "max": float(np.max(episode_rewards)),
                "min": float(np.min(episode_rewards))
            }
        }
        return samples, sample_info

    def process_samples(self, samples):
        raise NotImplementedError()

    def update_model(self, processed_samples):
        raise NotImplementedError()

    # ===== Training iteration =====
    def train(self):
        """Here we defined the training pipeline using the abstract
        functions."""
        info = dict(iteration=self.iteration)

        # [TODO] Uncomment the following block and go through the learning 
        # pipeline.
        
        # Collect samples
        samples, sample_info = self.collect_samples()
        info.update(sample_info)

        # Process samples
        processed_samples, processed_info = self.process_samples(samples)
        info.update(processed_info)

        # Update the model
        update_info = self.update_model(processed_samples)
        info.update(update_info)
        
        #pass

        now = time.time()
        self.iteration += 1
        self.total_timesteps += info["iter_timesteps"]
        self.total_episodes += info["iter_episodes"]
        info["iter_time"] = now - self.iteration_time
        info["total_time"] = now - self.start_time
        info["total_episodes"] = self.total_episodes
        info["total_timesteps"] = self.total_timesteps
        self.iteration_time = now
        return info

# %%
# Run this cell without modification

class TestAbstractTrainer(AbstractTrainer):
    def build_model(self):
        pass
    def compute_action(self, _):
        return np.random.choice(self.act_dim)
test_trainer = TestAbstractTrainer()
s, s_info = test_trainer.collect_samples()
assert len(s["obs"]) == s_info["iter_episodes"]
for i in range(len(s["obs"])):
    assert s["obs"][i].shape[0] <= default_config["max_episode_length"]
    assert len(s["act"][i]) == len(s["obs"][i]) == len(s["reward"][i])
assert abs(s_info["training_episode_length"]["mean"] * s_info["iter_episodes"]
           - s_info["iter_timesteps"]) < 1
print("Test Passed!")
# Out:
# Test Passed!

# %% [markdown]
# Now we have an abstract trainer class here. We have abstracted the learning process into three phases: Collect samples, process samples and update the model. In the following sections, we will continue to fulfill the blank functions.

# %% [markdown]
# ## Section 2: Basic policy gradient method
#
# (40 / 100 points)
#
# Unlike supervised learning, in RL setting the signal: reward and the output of neural network: the action distribution parameter (like the logits in discrete case or the mean in continous case) have no direct connection in terms of gradient. That is, you can't compute the gradient from the environment to your network output.
#
# To leverage the powerful tool of gradient descent, scientists innovated a technique called policy gradient, which is computed on top of the rewards and policy network's output. Scientists prove that: the policy gradient is the gradient of expected return w.r.t. the output. So that by applying gradient descent to gradient descent algorithm you can optimize your policy network and maximize the expected return (or minimize the negative of expected return).
#
# Concretely, if we consider the expected return, the value we want to maximize, is:
#
# $$Q = \mathbb E_{\text{possible trajectories}} \sum_t r(a_t, s_t) = \sum_{s_0, a_0,..} p(s_0, a_0, ..., s_t, a_t) r(s_0, a_0, ..., s_t, a_t) = \sum_{\tau} p(\tau)r(\tau)$$
#
# wherein $\sum_t r(a_t, s_t) = r(s_0, a_0, ..., s_t, a_t) = r(\tau)$ is the trajectory return. We use $\tau$ to represent a trajectory $s_0, a_0, ..., s_t, a_t$. Note that we remove the discount factor for simplicity.
#
# Since we want to maximize Q, we can simply compute the gradient from Q to parameter $\theta$ (which is included in the action probability $p(a_t)$):
#
# $$\nabla_\theta Q = \nabla_\theta \sum_{\tau} p(\tau)r(\tau) = \sum_{\tau} r(\tau) \nabla_\theta p(\tau)$$
#
# Scientists use a famous trick to deal with the gradient of probability of trajectory: $\nabla_\theta p(\tau) = p(\tau)\cfrac{\nabla_\theta p(\tau)}{p(\tau)} = p(\tau)\nabla_\theta \log p(\tau)$.
#
# The reason for this trick is that the probability of a trajectory is the product of all related probabilities of states and actions. So introducing a log term can change the production to summation: $p_\theta(\tau) = p(s_0, a_0, ...) = p(s_0) \prod_t \pi_\theta (a_t|s_t) p(s_{t+1}|s_t, a_t)$ Now we can expand the log of product above to sum of log:
#
# $$\log p_\theta (\tau) = \log p(s_1) + \sum_t \log \pi_\theta(a_t|s_t) + \sum_t \log p(s_{t+1}|s_t, a_t)$$
#
# You will find that the first and third term are not related to the parameter of policy $\pi_\theta(\cdot)$. So when we back to $\nabla_\theta Q$, we find
#
# $$\nabla_\theta Q = \sum_{\tau} r(\tau) \nabla_\theta p(\tau) =  \sum p_\theta(\tau) ( \sum_t  \nabla_\theta \log \pi_\theta(a_t|s_t) ) r(\tau) d\tau$$
#
# We use reward-to-go as $r(\tau)$ to reduce variance. The probability of trajectory is included when we sampled sufficient data from environment (Yes, so REINFORCE is a Monte Carlo algorithm) so the final form of policy gradient is:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'=t} \gamma^{t'-t} r(s_{i,t'}, a_{i,t'}) )]$$
#
# This algorithm is called REINFORCE algorithm, which is a Monte Carlo Policy Gradient algorithm having long history. In this section, we will implement the it using pytorch.

# %% [markdown]
# The policy network is composed by two parts: a basic MLP serve as function approximator which predict the probabilities of actions given the observation; and a distribution layer building upon the MLP to wrap the raw logits output of neural network to a distribution and provides API for action sampling and log probability retrieving.

# %%
# Run this cell without modification

class Net(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_units=128):
        super(Net, self).__init__()
        self.fc0 = nn.Linear(obs_dim, hidden_units)
        self.fc1 = nn.Linear(hidden_units, act_dim)

    def forward(self, x):
        x = x.type_as(self.fc0.bias)
        x = F.relu(self.fc0(x))
        x = self.fc1(x)
        x = F.softmax(x,dim=-1)
        return x


class CategoricalPolicy(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden_units=128):
        super(CategoricalPolicy, self).__init__()
        self.network = Net(obs_dim, act_dim, hidden_units)

    def forward(self, obs):
        logit = self.network(obs)
        
        # [TODO] Create an object of the class "Categorical" in torch 
        # package "distributions". Then sample an action from it.
        action = None
        p = torch.distributions.Categorical(logit)
        action = p.sample()
        #pass
        
        return action

    def log_prob(self, obs, act):
        logits = self.network(obs)
        
        # [TODO] Create an object of the class "Categorical" in torch 
        # package "distributions". Then collect the log probability of
        # the action in this distribution.
        log_prob = None
        p = torch.distributions.Categorical(logits)
        log_prob = p.log_prob(act)
        #pass
        
        return log_prob

# Not that we do not implement GaussianPolicy here. So we can't
# apply our algorithm to the environment with continous action.

# %%
# Solve the TODOs and remove `pass`

pg_default_config = merge_config(dict(
    normalize_advantage=True,
    clip_gradient=10.0,
    hidden_units=64,
), default_config)


class PGTrainer(AbstractTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, pg_default_config)
        super().__init__(config)

    def build_model(self):
        """Build the policy network and related optimizer"""
        # Detect whether you have GPU or not. Remember to call X.to(self.device)
        # if necessary.
        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu"
        )
        
        # [TODO] Build the policy network using CategoricalPolicy
        # Hint: Remember to pass config["hidden_units"], and set policy network
        #  to the device you are using.
        self.policy = None
        self.policy = CategoricalPolicy(self.obs_dim, self.act_dim,self.config["hidden_units"]).to(self.device)
        #pass
        
        # Build the Adam optimizer.
        self.optimizer = torch.optim.Adam(
            self.policy.parameters(),
            lr=self.config["learning_rate"]
        )

    def to_tensor(self, array):
        """Transform a numpy array to a pytorch tensor"""
        return torch.from_numpy(array).to(self.device)

    def to_array(self, tensor):
        """Transform a pytorch tensor to a numpy array"""
        return tensor.cpu().detach().numpy()

    def compute_action(self, observation):
        """Compute the action for single observation"""
        assert observation.ndim == 1
        # [TODO] Sample an action from action distribution given by the policy
        # Hint: The input of policy network is a batch of data, so you need to
        #  expand the first dimension of observation before feeding it to policy network.
        action = None
        observation = self.to_tensor(observation)
        observation = observation.view(1,-1)
        action = self.policy(observation)
        return action.item()
        #pass

    def compute_log_probs(self, observation, action):
        """Compute the log probabilities of a batch of state-action pair"""
        # [TODO] Using the function of policy network to get log probs.
        # Hint: Remember to transform the data into tensor before feeding it.
        observation = self.to_tensor(observation)
        action = self.to_tensor(action)
        log_probs =  self.policy.log_prob(observation,action)
        return log_probs
        #pass

    def process_samples(self, samples):
        """Process samples and add advantages in it"""
        values = []
        for reward_list in samples["reward"]:
            # reward_list contains rewards in one episode
            returns = np.zeros_like(reward_list, dtype=np.float32)
            Q = 0
            
            # [TODO] Scan the episode in a reverse order and compute the
            # discounted return at each time step. Fill the array `returns`
            # Hint: returns[n-1] = r_n-1
            #       returns[n-2] = r_n-2 + gamma * r_n-1
            #       ...
            #       returns[0] = r_0 + gamma * r_1 + gamma^2 * r_2 + ...
            #  wherein n is len(reward_list)
            for i,reward in enumerate(reversed(reward_list)):
                Q = reward+self.config["gamma"]*Q
                returns[-1-i] = Q
            #pass
            values.append(returns)

        # We call the values advantage here.
        advantages = np.concatenate(values)

        if self.config["normalize_advantage"]:
            # [TODO] normalize the advantage so that it's mean is
            # almost 0 and the its standard deviation is almost 1.
            advantages -= np.mean(advantages)
            advantages /= np.std(advantages)
            #pass
        
        samples["advantages"] = advantages
        return samples, {}

    def update_model(self, processed_samples):
        """A wrapper function, call self.update_policy"""
        return self.update_policy(processed_samples)

    def update_policy(self, processed_samples):
        """Update the policy network"""
        advantages = self.to_tensor(processed_samples["advantages"])
        flat_obs = np.concatenate(processed_samples["obs"])
        flat_act = np.concatenate(processed_samples["act"])

        self.policy.train()
        self.optimizer.zero_grad()

        log_probs = self.compute_log_probs(flat_obs, flat_act)

        assert log_probs.shape == advantages.shape, "log_probs shape {} is not " \
            "compatible with advantages {}".format(log_probs.shape, advantages.shape)
        
        # [TODO] Compute the loss using log probabilities and advantages.
        loss = None
        loss = -(log_probs*advantages).sum() 
        #pass
        
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.policy.parameters(), self.config["clip_gradient"]
        )

        self.optimizer.step()
        self.policy.eval()
        update_info = {
            "policy_loss": loss.item(),
            "mean_log_prob": torch.mean(log_probs).item(),
            "mean_advantage": torch.mean(advantages).item()
        }
        return update_info

# %%
# Run this cell without modification

# Test advantage computing
test_trainer = PGTrainer({"normalize_advantage": False})
test_trainer.train()
fake_sample = {"reward": [[2, 2, 2, 2, 2]]}
assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["reward"][0],
    fake_sample["reward"][0]
)
assert_almost_equal(
    test_trainer.process_samples(fake_sample)[0]["advantages"],
    np.array([9.80199, 7.880798, 5.9402, 3.98, 2.], dtype=np.float32)
)

# Test advantage normalization
test_trainer = PGTrainer(
    {"normalize_advantage": True, "env_name": "LunarLander-v2"})
test_adv = test_trainer.process_samples(fake_sample)[0]["advantages"]
assert_almost_equal(test_adv.mean(), 0.0)
assert_almost_equal(test_adv.std(), 1.0)

# Test the shape of functions' returns
fake_observation = np.array([
    test_trainer.env.observation_space.sample() for i in range(10)
])
fake_action = np.array([
    test_trainer.env.action_space.sample() for i in range(10)
])
assert test_trainer.to_tensor(fake_observation).shape == torch.Size([10, 8])
assert np.array(test_trainer.compute_action(fake_observation[0])).shape == ()
assert test_trainer.compute_log_probs(fake_observation, fake_action).shape == \
       torch.Size([10])

print("Test Passed!")
# Out:
# Test Passed!
# C:\Anaconda3\envs\ierg6130\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Run this cell without modification

pg_trainer_no_na, pg_result_no_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    normalize_advantage=False,  # <<== Here!
), 195.0)
# Out:
# === PGTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: false
#   seed: 0
#   train_batch_size: 200
#
# === PGTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   evaluate_reward: 23.18
#   iter_episodes: 10
#   iter_time: 0.0890040397644043
#   iter_timesteps: 217
#   iteration: 0
#   mean_advantage: 11.939602851867676
#   mean_log_prob: -0.6919979453086853
#   performance: 21.7
#   policy_loss: 1793.763427734375
#   total_episodes: 10
#   total_time: 0.0890040397644043
#   total_timesteps: 217
#   training_episode_length:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#   training_episode_reward:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#
# === PGTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   evaluate_reward: 58.24
#   iter_episodes: 3
#   iter_time: 0.07814931869506836
#   iter_timesteps: 246
#   iteration: 10
#   mean_advantage: 34.35287094116211
#   mean_log_prob: -0.6174345016479492
#   performance: 82.0
#   policy_loss: 5194.11328125
#   total_episodes: 63
#   total_time: 1.244506597518921
#   total_timesteps: 2549
#   training_episode_length:
#     max: 123.0
#     mean: 82.0
#     min: 59.0
#   training_episode_reward:
#     max: 123.0
#     mean: 82.0
#     min: 59.0
#
# === PGTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   evaluate_reward: 100.46
#   iter_episodes: 3
#   iter_time: 0.09377932548522949
#   iter_timesteps: 245
#   iteration: 20
#   mean_advantage: 32.579036712646484
#   mean_log_prob: -0.6084087491035461
#   performance: 81.66666666666667
#   policy_loss: 4873.60595703125
#   total_episodes: 96
#   total_time: 2.7798330783843994
#   total_timesteps: 5005
#   training_episode_length:
#     max: 94.0
#     mean: 81.66666666666667
#     min: 64.0
#   training_episode_reward:
#     max: 94.0
#     mean: 81.66666666666667
#     min: 64.0
#
# === PGTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   evaluate_reward: 138.96
#   iter_episodes: 3
#   iter_time: 0.09533309936523438
#   iter_timesteps: 272
#   iteration: 30
#   mean_advantage: 46.58760452270508
#   mean_log_prob: -0.6039609313011169
#   performance: 90.66666666666667
#   policy_loss: 7558.833984375
#   total_episodes: 120
#   total_time: 5.1108057498931885
#   total_timesteps: 7715
#   training_episode_length:
#     max: 200.0
#     mean: 90.66666666666667
#     min: 27.0
#   training_episode_reward:
#     max: 200.0
#     mean: 90.66666666666667
#     min: 27.0
#
# === PGTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   evaluate_reward: 175.12
#   iter_episodes: 2
#   iter_time: 0.12607455253601074
#   iter_timesteps: 371
#   iteration: 40
#   mean_advantage: 54.99089813232422
#   mean_log_prob: -0.5928562879562378
#   performance: 185.5
#   policy_loss: 12080.87890625
#   total_episodes: 140
#   total_time: 8.157227039337158
#   total_timesteps: 10924
#   training_episode_length:
#     max: 200.0
#     mean: 185.5
#     min: 171.0
#   training_episode_reward:
#     max: 200.0
#     mean: 185.5
#     min: 171.0
#
# === PGTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   evaluate_reward: 161.72
#   iter_episodes: 2
#   iter_time: 0.17192840576171875
#   iter_timesteps: 396
#   iteration: 50
#   mean_advantage: 56.83638000488281
#   mean_log_prob: -0.5828351378440857
#   performance: 198.0
#   policy_loss: 13076.001953125
#   total_episodes: 161
#   total_time: 11.804117202758789
#   total_timesteps: 14241
#   training_episode_length:
#     max: 200.0
#     mean: 198.0
#     min: 196.0
#   training_episode_reward:
#     max: 200.0
#     mean: 198.0
#     min: 196.0
#
# === PGTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   evaluate_reward: 173.6
#   iter_episodes: 2
#   iter_time: 0.18041348457336426
#   iter_timesteps: 400
#   iteration: 60
#   mean_advantage: 57.131980895996094
#   mean_log_prob: -0.5676707625389099
#   performance: 200.0
#   policy_loss: 13028.9755859375
#   total_episodes: 182
#   total_time: 15.874668598175049
#   total_timesteps: 17720
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PGTrainer CartPole-v0 Iteration 70 ===
# Training Progress:
#   evaluate_reward: 195.84
#   iter_episodes: 2
#   iter_time: 0.17352604866027832
#   iter_timesteps: 400
#   iteration: 70
#   mean_advantage: 57.131980895996094
#   mean_log_prob: -0.5589452981948853
#   performance: 200.0
#   policy_loss: 12739.451171875
#   total_episodes: 202
#   total_time: 20.107575178146362
#   total_timesteps: 21213
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# In 70 iteration, current mean episode reward 195.840 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_trainer_na, pg_result_na = run(PGTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
    normalize_advantage=True,  # <<== Here!
), 195.0)
# Out:
# === PGTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   seed: 0
#   train_batch_size: 200
#
# === PGTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   evaluate_reward: 27.24
#   iter_episodes: 10
#   iter_time: 0.08100342750549316
#   iter_timesteps: 217
#   iteration: 0
#   mean_advantage: -1.5381843354589364e-08
#   mean_log_prob: -0.6919979453086853
#   performance: 21.7
#   policy_loss: 0.11937487125396729
#   total_episodes: 10
#   total_time: 0.08100342750549316
#   total_timesteps: 217
#   training_episode_length:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#   training_episode_reward:
#     max: 32.0
#     mean: 21.7
#     min: 9.0
#
# === PGTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   evaluate_reward: 67.16
#   iter_episodes: 2
#   iter_time: 0.10940861701965332
#   iter_timesteps: 248
#   iteration: 10
#   mean_advantage: -1.509343405814434e-07
#   mean_log_prob: -0.6186388731002808
#   performance: 124.0
#   policy_loss: -0.6669702529907227
#   total_episodes: 67
#   total_time: 1.4387669563293457
#   total_timesteps: 2526
#   training_episode_length:
#     max: 169.0
#     mean: 124.0
#     min: 79.0
#   training_episode_reward:
#     max: 169.0
#     mean: 124.0
#     min: 79.0
#
# === PGTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   evaluate_reward: 123.32
#   iter_episodes: 3
#   iter_time: 0.10940933227539062
#   iter_timesteps: 244
#   iteration: 20
#   mean_advantage: 1.9444793508682778e-07
#   mean_log_prob: -0.6076633334159851
#   performance: 81.33333333333333
#   policy_loss: 2.99189829826355
#   total_episodes: 100
#   total_time: 3.733219861984253
#   total_timesteps: 5084
#   training_episode_length:
#     max: 115.0
#     mean: 81.33333333333333
#     min: 64.0
#   training_episode_reward:
#     max: 115.0
#     mean: 81.33333333333333
#     min: 64.0
#
# === PGTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   evaluate_reward: 173.5
#   iter_episodes: 2
#   iter_time: 0.17192745208740234
#   iter_timesteps: 385
#   iteration: 30
#   mean_advantage: 1.7958801379336364e-07
#   mean_log_prob: -0.5720041990280151
#   performance: 192.5
#   policy_loss: -8.29409408569336
#   total_episodes: 123
#   total_time: 7.195425748825073
#   total_timesteps: 7925
#   training_episode_length:
#     max: 200.0
#     mean: 192.5
#     min: 185.0
#   training_episode_reward:
#     max: 200.0
#     mean: 192.5
#     min: 185.0
#
# === PGTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   evaluate_reward: 185.6
#   iter_episodes: 2
#   iter_time: 0.14482641220092773
#   iter_timesteps: 400
#   iteration: 40
#   mean_advantage: 6.973743182925318e-08
#   mean_log_prob: -0.5700274109840393
#   performance: 200.0
#   policy_loss: -0.41051149368286133
#   total_episodes: 143
#   total_time: 11.222423315048218
#   total_timesteps: 11736
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# === PGTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   evaluate_reward: 173.5
#   iter_episodes: 2
#   iter_time: 0.14066767692565918
#   iter_timesteps: 363
#   iteration: 50
#   mean_advantage: 1.563185207942297e-07
#   mean_log_prob: -0.5274372100830078
#   performance: 181.5
#   policy_loss: -9.067272186279297
#   total_episodes: 163
#   total_time: 15.244328737258911
#   total_timesteps: 15117
#   training_episode_length:
#     max: 188.0
#     mean: 181.5
#     min: 175.0
#   training_episode_reward:
#     max: 188.0
#     mean: 181.5
#     min: 175.0
#
# === PGTrainer CartPole-v0 Iteration 60 ===
# Training Progress:
#   evaluate_reward: 200.0
#   iter_episodes: 2
#   iter_time: 0.1707592010498047
#   iter_timesteps: 400
#   iteration: 60
#   mean_advantage: 6.973743182925318e-08
#   mean_log_prob: -0.49633103609085083
#   performance: 200.0
#   policy_loss: -3.438786029815674
#   total_episodes: 183
#   total_time: 19.479121923446655
#   total_timesteps: 19074
#   training_episode_length:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#   training_episode_reward:
#     max: 200.0
#     mean: 200.0
#     min: 200.0
#
# In 60 iteration, current mean episode reward 200.000 is greater than reward threshold 195.0. Congratulation! Now we exit the training process.

# %%
# Run this cell without modification

pg_result_no_na["normalize_advantage"] = False
pg_result_na["normalize_advantage"] = True
pg_result = pd.concat([pg_result_no_na, pg_result_na])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="normalize_advantage",
)
ax.set_title("Policy Gradient")
# Out:
# Text(0.5, 1.0, 'Policy Gradient')

# %% [markdown]
# ## Section 3: Policy gradient with baseline
#
# (25 / 100 points)
#
# Recall the REINFORCE algorithm above. We compute the gradient of $Q = \mathop{\mathbb E} \sum_t r(a_t, s_t)$ w.r.t. the parameter to update the policy. A natural question is that, when you take an inferior action that lead to positive expected return, the policy gradient is also positive and you will update your network toward this action. At the same time a potential better action is ignored.
#
# To tackle this problem, we introduce "baseline" when computing the policy gradient. The insight behind this is that we want to optimize the policy toward an action that are better than the average performance when taking all action into consideration at a given state.
#
# We introduce $b_{t} = \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$ as the baseline. It average all possible actions at state $s_t$. So that the profit achieved by action $a_t$ can be evaluated via $\sum_{t'=t} \gamma^{t' -t}r(a_{t'}, s_{t'}) - b_t$
#
# Therefore, the policy gradient becomes:
#
# $$\nabla_\theta Q =\cfrac{1}{N}\sum_{i=1}^N [( \sum_t  \nabla_\theta \log \pi_\theta(a_{i,t}|s_{i,t}) (\sum_{t'} \gamma^{t'-t} r(s_{i,{t’}}, a_{i,t‘}) - b_{i, t})]$$
#
# In our implementation, we estimate the baseline via an extra network `self.baseline`, which has same structure of policy network but output only a scalar value. We use the output of this network to serve as the baseline, while this network is updated by fitting the true value of expected return of current state: $\mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}$
#
# In implementation, we use a trick to match the distribution of baseline and values. During training, we first collect a batch of target values: $\{t_i= \mathbb E_{a_t} \sum_{t'}{\gamma^{t'-t} r(s_{t'}, a_{t'})}\}_i$. Then we normalzie all targets to standard distribution with mean = 0 and std = 1. Then we ask the baseline network to fit such normalized targets.
#
# When computing the advantages, instead of using the output of baseline network as the baseline $b$, we firstly match the baseline distribution with action values. The transformed baselines $b' = f(b)$ should has the same means of action values and same std of action values too. Then we compute the advantage of current action: $adv_{i,t} = \sum_{t'} \gamma^{t'-t} r(s_{i,{t'}}, a_{i,t'}) - b'_{i, t}$
#
# By doing this, we mitigate the instability of training baseline.
#
# Hint: We suggest to normalize an array via: `(x - x.mean()) / max(x.std(), 1e-6)`. The max term can avoid potential risk of error.

# %%
pg_with_baseline_default_config = merge_config(dict(), pg_default_config)

class PolicyGradientWithBaselineTrainer(PGTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, pg_with_baseline_default_config)
        super().__init__(config)

    def build_model(self):
        # Build the actor in name of self.policy
        super().build_model()
        
        # [TODO] Build the baseline network using Net class.
        # Remember that you need to set the output dimension to 1.
        # Remember using model.to(device) function to move your model to GPU (if applicable)
        self.baseline = None
        self.baseline = Net(self.obs_dim, 1, self.config["hidden_units"]).to(self.device)
        #pass
        
        self.baseline_loss = nn.MSELoss()
            
        self.baseline_optimizer = torch.optim.Adam(
            self.baseline.parameters(),
            lr=self.config["learning_rate"]
        )

    def process_samples(self, samples):
        # Call the original process_samples function to get advantages
        tmp_samples, _ = super().process_samples(samples)
        values = tmp_samples["advantages"]
        samples["values"] = values  # We add q_values into samples

        # [TODO] flatten the observations in all trajectories (still a numpy array)
        obs = None
        obs = np.concatenate(tmp_samples["obs"])
        #pass
        
        assert obs.ndim == 2
        assert obs.shape[1] == self.obs_dim
        
        obs = self.to_tensor(obs)
        samples["flat_obs"] = obs

        # [TODO] Compute the baseline by feeding observation to baseline network
        # Hint: baselines turns out to be a numpy array with the same shape of `values`,
        #  that is: (batch size, )
        baselines = None
        baselines = self.to_array(self.baseline(obs).flatten())
        #pass
        
        assert baselines.shape == values.shape
        
        # [TODO] Match the distribution of baselines to the values.
        # Hint: We expect to see baselines.std almost equals to values.std, 
        #  and baselines.mean almost equals to values.mean
        baselines += values.mean()-baselines.mean()
        baselines *= values.std()/(baselines.std()+1e-6)
        #pass

        # Compute the advantage
        advantages = values - baselines
        samples["advantages"] = advantages
        process_info = {"mean_baseline": float(np.mean(baselines))}
        return samples, process_info

    def update_model(self, processed_samples):
        update_info = {}
        update_info.update(self.update_baseline(processed_samples))
        update_info.update(self.update_policy(processed_samples))
        return update_info

    def update_baseline(self, processed_samples):
        self.baseline.train()
        obs = processed_samples["flat_obs"]

        # [TODO] Normalize the values to mean=0, std=1.
        values = processed_samples["values"]
        values -= values.mean()
        values /= values.std()+1e-6
        #pass
        
        values = self.to_tensor(values[:, np.newaxis])
        
        baselines = self.baseline(obs)

        self.baseline_optimizer.zero_grad()
        loss = self.baseline_loss(input=baselines, target=values)
        loss.backward()
        
        # Clip the gradient
        torch.nn.utils.clip_grad_norm_(
            self.baseline.parameters(), self.config["clip_gradient"]
        )
        
        self.baseline_optimizer.step()
        self.baseline.eval()
        return dict(baseline_loss=loss.item())

# %%
# Run this cell without modification

pg_trainer_wb, pgwb_result_wb = run(PolicyGradientWithBaselineTrainer, dict(
    learning_rate=0.01,
    max_episode_length=200,
    train_batch_size=200,
), 195.0)
# Out:
# === PolicyGradientWithBaselineTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.01
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   seed: 0
#   train_batch_size: 200
#
# mean 1.0
# max 1.0
# std 0.0
# vmean -5.475642e-08
# vmax 3.0569022
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   baseline_loss: 1.9999980926513672
#   evaluate_reward: 24.0
#   iter_episodes: 11
#   iter_time: 0.14643430709838867
#   iter_timesteps: 209
#   iteration: 0
#   mean_advantage: -4.2778452780112275e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.6912497878074646
#   performance: 19.0
#   policy_loss: 0.24247002601623535
#   total_episodes: 11
#   total_time: 0.14643430709838867
#   total_timesteps: 209
#   training_episode_length:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#   training_episode_reward:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean 4.9541523e-08
# vmax 2.969395
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.6302126e-08
# vmax 2.5926583
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.2768861e-07
# vmax 2.8568125
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -6.253602e-08
# vmax 2.3299665
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.4609479e-07
# vmax 2.127626
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 6.152737e-08
# vmax 1.6442429
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -9.8006055e-08
# vmax 2.4578605
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.119336e-07
# vmax 2.112001
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.0499167e-07
# vmax 2.3490517
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 0.0
# vmax 1.6674738
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 10 ===
# Training Progress:
#   baseline_loss: 1.9999979734420776
#   evaluate_reward: 58.7
#   iter_episodes: 3
#   iter_time: 0.13715314865112305
#   iter_timesteps: 255
#   iteration: 10
#   mean_advantage: 5.14236164761428e-09
#   mean_baseline: 0.0
#   mean_log_prob: -0.6250002384185791
#   performance: 85.0
#   policy_loss: 0.2824394106864929
#   total_episodes: 76
#   total_time: 1.8969111442565918
#   total_timesteps: 2579
#   training_episode_length:
#     max: 157.0
#     mean: 85.0
#     min: 24.0
#   training_episode_reward:
#     max: 157.0
#     mean: 85.0
#     min: 24.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean -7.0353025e-08
# vmax 1.946715
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.8428489e-08
# vmax 1.7009883
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.785603e-07
# vmax 2.1355274
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -9.5802896e-08
# vmax 1.6449397
# vstd 0.9999998
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -2.4143654e-08
# vmax 1.8362674
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 6.8363754e-08
# vmax 1.8621237
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.2655394e-07
# vmax 1.8800765
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -2.5562403e-07
# vmax 1.9523034
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.1387156e-07
# vmax 1.6787354
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -4.3775213e-08
# vmax 1.5541093
# vstd 0.9999999
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 20 ===
# Training Progress:
#   baseline_loss: 1.9999982118606567
#   evaluate_reward: 114.86
#   iter_episodes: 3
#   iter_time: 0.13875484466552734
#   iter_timesteps: 305
#   iteration: 20
#   mean_advantage: -4.7292864735482e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.610688328742981
#   performance: 101.66666666666667
#   policy_loss: -5.964768409729004
#   total_episodes: 110
#   total_time: 4.210561275482178
#   total_timesteps: 5087
#   training_episode_length:
#     max: 128.0
#     mean: 101.66666666666667
#     min: 52.0
#   training_episode_reward:
#     max: 128.0
#     mean: 101.66666666666667
#     min: 52.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.3443866e-07
# vmax 1.8164377
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -2.0461297e-08
# vmax 1.6296233
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.4362566e-07
# vmax 1.70309
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.5197998e-08
# vmax 1.8043495
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.01527526e-07
# vmax 1.6233664
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 2.705459e-08
# vmax 1.4809664
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 8.20365e-08
# vmax 1.5295142
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -2.3403051e-07
# vmax 1.6755714
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -6.233166e-08
# vmax 1.4924178
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -5.1549964e-08
# vmax 1.4936732
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 30 ===
# Training Progress:
#   baseline_loss: 1.9999982118606567
#   evaluate_reward: 144.16
#   iter_episodes: 2
#   iter_time: 0.13730740547180176
#   iter_timesteps: 296
#   iteration: 30
#   mean_advantage: -6.041011602064827e-08
#   mean_baseline: 0.0
#   mean_log_prob: -0.5993425250053406
#   performance: 148.0
#   policy_loss: 4.61363410949707
#   total_episodes: 135
#   total_time: 7.774189233779907
#   total_timesteps: 7863
#   training_episode_length:
#     max: 200.0
#     mean: 148.0
#     min: 96.0
#   training_episode_reward:
#     max: 200.0
#     mean: 148.0
#     min: 96.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.6232754e-07
# vmax 1.3141671
# vstd 0.9999999
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.0249771e-07
# vmax 1.4757677
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.1228746e-07
# vmax 1.4896295
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -2.5262896e-08
# vmax 1.4939207
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 7.6293944e-08
# vmax 1.2229471
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 0.0
# vmax 1.4702731
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 3.9326775e-08
# vmax 1.2688948
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.4041831e-07
# vmax 1.3501182
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 7.597955e-08
# vmax 1.5929476
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -6.5488365e-08
# vmax 1.5168681
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 40 ===
# Training Progress:
#   baseline_loss: 1.9999980926513672
#   evaluate_reward: 147.14
#   iter_episodes: 2
#   iter_time: 0.12502551078796387
#   iter_timesteps: 233
#   iteration: 40
#   mean_advantage: 0.11920925974845886
#   mean_baseline: -0.11920928955078125
#   mean_log_prob: -0.5852623581886292
#   performance: 116.5
#   policy_loss: 17.204500198364258
#   total_episodes: 156
#   total_time: 11.906984567642212
#   total_timesteps: 11159
#   training_episode_length:
#     max: 173.0
#     mean: 116.5
#     min: 60.0
#   training_episode_reward:
#     max: 173.0
#     mean: 116.5
#     min: 60.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.1057094e-07
# vmax 1.4051604
# vstd 0.9999999
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 3.892548e-08
# vmax 1.3687483
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.09382e-07
# vmax 1.4654354
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.18387156e-07
# vmax 1.3640729
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -4.161488e-08
# vmax 1.4784104
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.8738864e-07
# vmax 1.4142512
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 2.3991806e-08
# vmax 1.5635366
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 0.0
# vmax 1.5581105
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.4630231e-07
# vmax 1.3978904
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.472856e-07
# vmax 1.5581965
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# === PolicyGradientWithBaselineTrainer CartPole-v0 Iteration 50 ===
# Training Progress:
#   baseline_loss: 1.9999980926513672
#   evaluate_reward: 112.38
#   iter_episodes: 2
#   iter_time: 0.13166546821594238
#   iter_timesteps: 259
#   iteration: 50
#   mean_advantage: -0.1192091554403305
#   mean_baseline: 0.11920928955078125
#   mean_log_prob: -0.5962335467338562
#   performance: 129.5
#   policy_loss: -22.032249450683594
#   total_episodes: 177
#   total_time: 16.088006258010864
#   total_timesteps: 14030
#   training_episode_length:
#     max: 150.0
#     mean: 129.5
#     min: 109.0
#   training_episode_reward:
#     max: 150.0
#     mean: 129.5
#     min: 109.0
#
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.258976e-08
# vmax 1.426868
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -6.502325e-08
# vmax 1.3730685
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 5.035904e-08
# vmax 1.6142576
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -4.704223e-08
# vmax 1.5311997
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 2.1760425e-07
# vmax 1.5422901
# vstd 0.99999994
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 7.785096e-08
# vmax 1.4795018
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.929113e-07
# vmax 1.4219311
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.4910869e-07
# vmax 1.3646827
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean 1.4754961e-07
# vmax 1.4558452
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# mean 1.0
# max 1.0
# std 0.0
# vmean -1.273372e-07
# vmax 1.4096795
# vstd 1.0
# mean tensor(1., grad_fn=<MeanBackward0>)
# max tensor(1., grad_fn=<MaxBackward1>)
# std tensor(0., grad_fn=<StdBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-ce6c4f258376> in <module>
#       5     max_episode_length=200,
#       6     train_batch_size=200,
# ----> 7 ), 195.0)
#
# <ipython-input-2-3dae9e2e052d> in run(trainer_cls, config, reward_threshold)
#      22         if i % config['evaluate_interval'] == 0 or \
#      23                 i == config["max_iteration"]:
# ---> 24             reward = trainer.evaluate(config["evaluate_num_episodes"])
#      25             stat["evaluate_reward"] = reward
#      26             print("=== {} {} Iteration {} ===".format(
#
# <ipython-input-3-c6fca0ec0831> in evaluate(self, num_episodes, render)
#      60     def evaluate(self, num_episodes=10, render=False):
#      61         """Evaluate the agents for num_episodes episodes."""
# ---> 62         return evaluate_agent(self, self.env, num_episodes, render)
#      63
#      64     def to_tensor(self, array):
#
# ~\Desktop\毕设\code\ierg6130-assignment\assignment3\utils.py in evaluate_agent(pg_agent, env, num_episodes, render)
#      69
#      70             # Query the agent to get action
# ---> 71             act = pg_agent.compute_action(obs)
#      72
#      73             ep_reward += reward
#
# <ipython-input-6-32501d8be614> in compute_action(self, observation)
#      51         observation = self.to_tensor(observation)
#      52         observation = observation.view(1,-1)
# ---> 53         action = self.policy(observation)
#      54         return action.item()
#      55         #pass
#
# C:\Anaconda3\envs\ierg6130\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-5-65eca64c10c9> in forward(self, obs)
#      27         action = None
#      28         p = torch.distributions.Categorical(logit)
# ---> 29         action = p.sample()
#      30         #pass
#      31
#
# C:\Anaconda3\envs\ierg6130\lib\site-packages\torch\distributions\categorical.py in sample(self, sample_shape)
#     103         sample_shape = self._extended_shape(sample_shape)
#     104         param_shape = sample_shape + torch.Size((self._num_events,))
# --> 105         probs = self.probs.expand(param_shape)
#     106         if self.probs.dim() == 1 or self.probs.size(0) == 1:
#     107             probs_2d = probs.view(-1, self._num_events)
#
# KeyboardInterrupt:

# %%
# Run this cell without modification

pg_result_no_na["normalize_advantage"] = False
pg_result_na["normalize_advantage"] = True
pgwb_result_wb["normalize_advantage"] = "True with Baseline"
pg_result = pd.concat([pg_result_no_na, pg_result_na, pgwb_result_wb])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="normalize_advantage",
)
ax.set_title("Policy Gradient")
# Out:
# Text(0.5, 1.0, 'Policy Gradient')

# %%
# Run this cell without modification

# You should see a pop up window which display the movement of the cart and pole.
print("Average episode reward for your Policy Gradient agent in CartPole-v0: ",
      pg_trainer_wb.evaluate(1, render=True))
# Out:
# Average episode reward for your Policy Gradient agent in CartPole-v0:  200.0

# %% [markdown]
# ## Section 4: Actor-critic Method
#
# (30 / 100 points totally)
#
# ### Section 4.1: Implement ActorCriticTrainer
#
# (20 / 100 points)

# %% [markdown]
# As point out in the textbook Page 331, the difference of Actor-critic methods and policy gradient with baseline method is whether the critic (baseline) participates in the bootstrapping. In `PolicyGradientWithBaselineTrainer`, we update the baseline network by fitting the ground-truth Q values. However, in actor-critic trainer presented below, we update the critic via fitting a bootstrapped target:
#
# $$\delta = r_t + \gamma V(s_{t+1}) - V(s_t)$$
#
# wherein $V$ is the values predicted by critic. In `ActorCriticTrainer`, in order to reuse the codes, we use `self.baseline` to represent the critic network.

# %%
# Solve the TODOs and remove `pass`

ac_default_config = merge_config(dict(
    normalize_advantage=True,
    num_critic_updates=10,
    num_critic_update_steps=10
), pg_with_baseline_default_config)

class ActorCriticTrainer(PolicyGradientWithBaselineTrainer):
    def __init__(self, config=None):
        config = check_and_merge_config(config or {}, ac_default_config)
        super().__init__(config)
        
    def process_samples(self, samples):
        """
        In this function, we will compute the target of value function
        and also the advantage used for updating policy.
        
        First, we need to prepare data to compute the values.
        
        Consider you only collect two trajectories in samples.
        Then the data structure should be:
            samples["obs"] = [
                [
                    obs_t1_0,  <<= t=0
                    obs_t1_1,  <<= t=1
                    obs_t1_n1-1, <<= t=n1-1 
                ],  (the traj t1 has length = n1)
                [
                    obs_t2_0,
                    ...
                    obs_t2_n2-1 
                ]   (the traj t2 has length = n2)
            ]
        the whole training batch size is N = (n1 + n2).
        Then what you should do is to take store
        [
            obs_t1_1, ..., obs_t1_n1-1, ZERO, 
            obs_t2_1, ... obs_t2_n2-1, ZERO
        ]
        into `next_obs` variable, wherein ZERO is a zero array has
        same shape as any other observation.
        
        Besides, you also need to prepare a boolean array `masks`
        who has length N. It should be like:
        [
            False(0), ..., False(n1-2), True(n1-1),
            False(0), ..., False(n2-2), True(n2-1)
        ].
        It represents whether a transition is terminal transition
        and whether a observation in next_obs should be masked.
        We will used it when computing the bootstrapped values:
        
            value_t = reward_t + gamma * value_t+1 * (1 - masks)
            
        So that we will not consider the impact of value_t+1
        in terminal state.
        
        Then, we need to compute the values and advantage based on 
        the data collected and form a processed_samples for the 
        consecetive .
        """
        # Define the sum of all trajectory length as N (train batch size)
        N = sum([len(traj) for traj in samples["obs"]])
        n = len(samples["obs"][0])  # the first traj length
        
        # [TODO] Create an array named next_obs.
        # In each trajectory, take the observations from second
        # transitions to the end. Fill an extra all zero observation
        # at the end of trajectory to align next_obs with others.
        next_obs = []
        start_index = 0
        for obs_list in samples["obs"]:
            next_obs[start_index:len(obs_list)-1] = obs_list[1:]
            next_obs.append([0]*self.obs_dim)
            start_index+=len(obs_list)
            #pass
            
        next_obs = np.array(next_obs)
        
        assert next_obs.shape == (N, self.obs_dim)
        assert np.all(next_obs[n - 1] == 0.0)
        
        # [TODO] Scan all trajectories and create a boolean array `masks`.
        # It should be N length, N is the sum of the trajectories lengths.
        # You should loop over each trajectory and store n-1 False into masks
        # while storing one True at the end of each episode. n is the length
        # of current trajectory.
        # Finally, you should transform the list to an float32 array
        # with shape (N,)
        masks = []
        true_index = -1
        masks = [False]*N
        for obs_list in samples["obs"]:
            true_index += len(obs_list)
            masks[true_index] = True
            #pass
            
        masks = np.array(masks, dtype=np.float32)
        
        assert masks.shape == (N,)
        assert masks[n - 1] == True
        
        # flatten rewards
        rewards = np.concatenate(samples["reward"])
        tensor_rewards = self.to_tensor(rewards)
        
        # flatten observations
        obs = np.concatenate(samples["obs"])
        
        # [TODO] Compute the bootstrapped values
        # Hint: value_t = reward_t + gamma * value_t+1 * (1 - masks)
        #  You need to ask self.baseline using next_obs to get 
        #  the values in next state, then can you compute the 
        #  value_t.
        tensor_next_obs = self.to_tensor(next_obs)
        values = None
        values = rewards + self.config["gamma"]*self.to_array(self.baseline(tensor_next_obs).flatten())*(1-masks)
        #pass
        
        assert isinstance(values, np.ndarray)
        assert values.shape == (N,)
        
        # [TODO] Compute the baseline by feeding obs to critic
        tensor_obs = self.to_tensor(obs)
        baselines = None
        baselines = self.to_array(self.baseline(tensor_obs).flatten())
        #pass
        
        assert isinstance(baselines, np.ndarray)
        assert baselines.shape == (N,)
        
        # [TODO] Compute the advantages using values and baselines
        advantages = None
        advantages = values - baselines
        #pass
        
        if self.config["normalize_advantage"]:
            # [TODO] normalize the advantages
            advantages -= advantages.mean()
            advantages /= advantages.std()
            #pass
        
        # We passed part of numpy array and part of torch tensor
        # to the following modules.
        processed_samples = samples
        processed_samples["advantages"] = advantages
        processed_samples["tensor_next_obs"] = tensor_next_obs
        processed_samples["tensor_obs"] = tensor_obs
        processed_samples["tensor_rewards"] = tensor_rewards
        processed_samples["tensor_masks"] = self.to_tensor(masks)
        process_info = {
            "mean_baselines": float(np.mean(baselines)),
            "advantages_std": float(advantages.std())
        }  # You can add value here so that it will be printed automatically.
        return processed_samples, process_info
        
    def update_baseline(self, processed_samples):
        # Use a bootstrapped target values and update the critic.
        # Compute the target values r(s, a) + gamma * V(s') by calling
        # the critic to compute V(s').
        reward = processed_samples["tensor_rewards"]
        obs = processed_samples["tensor_obs"]
        next_obs = processed_samples["tensor_next_obs"]
        masks = processed_samples["tensor_masks"]
        
        assert masks.shape == reward.shape
        assert next_obs.shape == obs.shape
        
        losses = []
        
        for _ in range(self.config["num_critic_updates"]):  # Train critic for 10 iteration
            self.baseline.eval()
            
            # Predict the values of next state
            values_next = self.baseline(next_obs).reshape(reward.shape)  # a tensor
            
            assert values_next.shape == reward.shape  # tensor shape should equal
            
            # [TODO] Compute the target of critic using reward, masks
            # and values_next (don't forget gamma)
            # Hint: the masks are all False (that is, zero) when the state is not
            #  terminal state, and are True (one) when is. So we can use (1-masks)
            #  as a multiplier to apply to values_next when computing the target.
            target = None
            target = reward+self.config["gamma"]*values_next*(1-masks)
            #pass
            
            target = target.detach()
            self.baseline.train()

            for _ in range(self.config["num_critic_update_steps"]):
                # [TODO] Uncomment the whole section
                
                baselines = self.baseline(obs).reshape(reward.shape)
                loss = self.baseline_loss(input=baselines, target=target)
                self.baseline_optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(
                    self.baseline.parameters(), self.config["clip_gradient"]
                )
                self.baseline_optimizer.step()
                losses.append(loss.item())
                
                #pass
            
        self.baseline.eval()
        return {"critic_loss": np.mean(losses)}

# %%
# Run this cell without modification

ac_trainer, ac_result = run(ActorCriticTrainer, dict(
    learning_rate=0.001,
    max_episode_length=200,
    train_batch_size=200,
), 195.0)
# Out:
# === ActorCriticTrainer CartPole-v0 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: CartPole-v0
#   evaluate_interval: 10
#   evaluate_num_episodes: 50
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.001
#   max_episode_length: 200
#   max_iteration: 1000
#   normalize_advantage: true
#   num_critic_update_steps: 10
#   num_critic_updates: 10
#   seed: 0
#   train_batch_size: 200
#
# 1.9378947
# 0.22106391
# 1.0
# 0.0
# 0.9378946
# 0.22106391
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# === ActorCriticTrainer CartPole-v0 Iteration 0 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 0.9285157918930054
#   evaluate_reward: 21.68
#   iter_episodes: 11
#   iter_time: 0.40872812271118164
#   iter_timesteps: 209
#   iteration: 0
#   mean_advantage: 7.278040925484675e-07
#   mean_baselines: 1.0
#   mean_log_prob: -0.6912497878074646
#   performance: 19.0
#   policy_loss: -0.735938310623169
#   total_episodes: 11
#   total_time: 0.40872812271118164
#   total_timesteps: 209
#   training_episode_length:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#   training_episode_reward:
#     max: 40.0
#     mean: 19.0
#     min: 12.0
#
# 1.9430805
# 0.210354
# 1.0
# 0.0
# 0.94308037
# 0.21035399
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# 1.9404999
# 0.2157655
# 1.0
# 0.0
# 0.9404999
# 0.2157655
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# 1.9515948
# 0.19117051
# 1.0
# 0.0
# 0.95159465
# 0.19117051
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# 1.94894
# 0.19739148
# 1.0
# 0.0
# 0.94893986
# 0.19739148
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# 1.9477726
# 0.20005512
# 1.0
# 0.0
# 0.9477723
# 0.20005512
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# ...
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# 1.9378947
# 0.22106393
# 1.0
# 0.0
# 0.9378946
# 0.22106391
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# mmmmmmmmmm tensor(1., grad_fn=<MeanBackward0>)
# ssssssssss tensor(0., grad_fn=<StdBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-ae5b687f425b> in <module>
#       5     max_episode_length=200,
#       6     train_batch_size=200,
# ----> 7 ), 195.0)
#
# <ipython-input-2-3dae9e2e052d> in run(trainer_cls, config, reward_threshold)
#      18     pretty_print({"Config": config})
#      19     for i in range(config['max_iteration'] + 1):
# ---> 20         stat = trainer.train()
#      21         stats.append(stat or {})
#      22         if i % config['evaluate_interval'] == 0 or \
#
# <ipython-input-3-c6fca0ec0831> in train(self)
#     162
#     163         # Collect samples
# --> 164         samples, sample_info = self.collect_samples()
#     165         info.update(sample_info)
#     166
#
# <ipython-input-3-c6fca0ec0831> in collect_samples(self)
#      94             episode_reward = 0
#      95             while True:
# ---> 96                 act = self.compute_action(obs)
#      97                 next_obs, reward, done, _ = self.env.step(act)
#      98
#
# <ipython-input-6-32501d8be614> in compute_action(self, observation)
#      51         observation = self.to_tensor(observation)
#      52         observation = observation.view(1,-1)
# ---> 53         action = self.policy(observation)
#      54         return action.item()
#      55         #pass
#
# C:\Anaconda3\envs\ierg6130\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-5-65eca64c10c9> in forward(self, obs)
#      21
#      22     def forward(self, obs):
# ---> 23         logit = self.network(obs)
#      24
#      25         # [TODO] Create an object of the class "Categorical" in torch
#
# C:\Anaconda3\envs\ierg6130\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-5-65eca64c10c9> in forward(self, x)
#       8
#       9     def forward(self, x):
# ---> 10         x = x.type_as(self.fc0.bias)
#      11         x = F.relu(self.fc0(x))
#      12         x = self.fc1(x)
#
# KeyboardInterrupt:

# %%
# Run this cell without modification

pg_result_na["label"] = "Pure PG"
pgwb_result_wb["label"] = "PG with Baseline"
ac_result["label"] = "Actor-critic"
pg_result = pd.concat([pg_result_na, pgwb_result_wb, ac_result])
ax = sns.lineplot(
    x="total_timesteps", 
    y="performance", 
    data=pg_result, hue="label",
)
ax.set_title("Policy Gradient")
# Out:
# Text(0.5, 1.0, 'Policy Gradient')

# %% [markdown]
# ### Section 4.2 -- Land on the Moon!
#
# (5 / 100 points)
#
# Let's try to land on the moon! In this section, we will try a harder environment: "LunarLander-v2". The agent needs to control the lander to land on a small interval of the moon marked by the flags. Due to the complex dynamic of rocket, the environment is hard to solve and it may take hours for you to train.
#
# The environment provides a 8-element vector as observation, which is different from the image observation provided by the following Pong environment in the next setion.

# %%
# Run this cell without modification
e = gym.make("LunarLander-v2"); e.reset()
frames = []
for _ in range(1000):
    frames.append(e.render("rgb_array"))
    if e.step(e.action_space.sample())[2]: break
e.close();animate(frames);del e
# Out:
# C:\Anaconda3\envs\ierg6130\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
import gym

# %%
e = gym.make("LunarLander-v2")

# %%
e.observation_space
# Out:
# Box(8,)

# %%
# Run this cell without modification

ac_trainer_lander, ac_result_lander = run(ActorCriticTrainer, dict(
    env_name="LunarLander-v2",
    max_iteration=500,
    learning_rate=0.005,
    max_episode_length=1000,
    train_batch_size=10000,
    normalize_advantage=True,
    evaluate_interval=1,
    evaluate_num_episodes=5,
), 200)

# Hint: 1. This would take hours to train on personal laptop.
#       2. Episode reward should greater than 0 after 80 iterations.
#       3. We are using purely on-policy algorithm, so we expect the performance 
#          to be highly unstable.
# Out:
# === ActorCriticTrainer LunarLander-v2 Training Start ===
# Config:
#   checked: true
#   clip_gradient: 10.0
#   env_name: LunarLander-v2
#   evaluate_interval: 1
#   evaluate_num_episodes: 5
#   gamma: 0.99
#   hidden_units: 64
#   learning_rate: 0.005
#   max_episode_length: 1000
#   max_iteration: 500
#   normalize_advantage: true
#   num_critic_update_steps: 10
#   num_critic_updates: 10
#   seed: 0
#   train_batch_size: 10000
#
# === ActorCriticTrainer LunarLander-v2 Iteration 0 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 126.0412368774414
#   evaluate_reward: -199.4165088540446
#   iter_episodes: 108
#   iter_time: 5.889418840408325
#   iter_timesteps: 10091
#   iteration: 0
#   mean_advantage: -3.0242373050271e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.3821500539779663
#   performance: -173.8101807112743
#   policy_loss: 19.506122589111328
#   total_episodes: 108
#   total_time: 5.889418840408325
#   total_timesteps: 10091
#   training_episode_length:
#     max: 150.0
#     mean: 93.43518518518519
#     min: 57.0
#   training_episode_reward:
#     max: 32.854696346265456
#     mean: -173.8101807112743
#     min: -446.7040970281293
#
# === ActorCriticTrainer LunarLander-v2 Iteration 1 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 122.6689682006836
#   evaluate_reward: -127.98933191414224
#   iter_episodes: 106
#   iter_time: 5.950906276702881
#   iter_timesteps: 10083
#   iteration: 1
#   mean_advantage: 6.904515181815896e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.37981116771698
#   performance: -180.92611818907486
#   policy_loss: -20.28291130065918
#   total_episodes: 214
#   total_time: 11.840325117111206
#   total_timesteps: 20174
#   training_episode_length:
#     max: 161.0
#     mean: 95.12264150943396
#     min: 59.0
#   training_episode_reward:
#     max: -16.155725284975176
#     mean: -180.92611818907486
#     min: -497.51845680795464
#
# === ActorCriticTrainer LunarLander-v2 Iteration 2 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 113.22295379638672
#   evaluate_reward: -202.9029441131715
#   iter_episodes: 99
#   iter_time: 6.817402601242065
#   iter_timesteps: 10022
#   iteration: 2
#   mean_advantage: 1.6176874950701858e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.374807596206665
#   performance: -164.8505935460554
#   policy_loss: -58.515987396240234
#   total_episodes: 313
#   total_time: 18.65772771835327
#   total_timesteps: 30196
#   training_episode_length:
#     max: 173.0
#     mean: 101.23232323232324
#     min: 62.0
#   training_episode_reward:
#     max: 7.432099318382072
#     mean: -164.8505935460554
#     min: -510.4590623628458
#
# === ActorCriticTrainer LunarLander-v2 Iteration 3 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 118.23017883300781
#   evaluate_reward: -117.87474580210953
#   iter_episodes: 100
#   iter_time: 5.744613170623779
#   iter_timesteps: 10012
#   iteration: 3
#   mean_advantage: -5.619934739797827e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.3671677112579346
#   performance: -171.45661044028537
#   policy_loss: -87.20044708251953
#   total_episodes: 413
#   total_time: 24.40234088897705
#   total_timesteps: 40208
#   training_episode_length:
#     max: 156.0
#     mean: 100.12
#     min: 58.0
#   training_episode_reward:
#     max: 10.571922304085277
#     mean: -171.45661044028537
#     min: -495.09065296067286
#
# === ActorCriticTrainer LunarLander-v2 Iteration 4 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 109.5926284790039
#   evaluate_reward: -164.44158889304157
#   iter_episodes: 95
#   iter_time: 6.817619323730469
#   iter_timesteps: 10077
#   iteration: 4
#   mean_advantage: 7.665735601847246e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.3640776872634888
#   performance: -178.70142063488524
#   policy_loss: -114.83003997802734
#   total_episodes: 508
#   total_time: 31.21996021270752
#   total_timesteps: 50285
#   training_episode_length:
#     max: 168.0
#     mean: 106.07368421052631
#     min: 63.0
#   training_episode_reward:
#     max: 14.354569930914025
#     mean: -178.70142063488524
#     min: -468.4885591435626
#
# === ActorCriticTrainer LunarLander-v2 Iteration 5 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 110.42637634277344
#   evaluate_reward: -243.3709933057524
#   iter_episodes: 93
#   iter_time: 5.855628490447998
#   iter_timesteps: 10060
#   iteration: 5
#   mean_advantage: 2.6543618414365255e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.3547086715698242
#   performance: -168.5572731227599
#   policy_loss: -163.68016052246094
#   total_episodes: 601
#   total_time: 37.07558870315552
#   total_timesteps: 60345
#   training_episode_length:
#     max: 199.0
#     mean: 108.17204301075269
#     min: 59.0
#   training_episode_reward:
#     max: 27.500367688226163
#     mean: -168.5572731227599
#     min: -423.64081925109156
#
# === ActorCriticTrainer LunarLander-v2 Iteration 6 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 104.08226776123047
#   evaluate_reward: -125.10670156268358
#   iter_episodes: 90
#   iter_time: 5.292874336242676
#   iter_timesteps: 10031
#   iteration: 6
#   mean_advantage: 1.0077706669164854e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.3399206399917603
#   performance: -179.95652383493857
#   policy_loss: -147.741943359375
#   total_episodes: 691
#   total_time: 42.36846303939819
#   total_timesteps: 70376
#   training_episode_length:
#     max: 198.0
#     mean: 111.45555555555555
#     min: 59.0
#   training_episode_reward:
#     max: -28.507610799970777
#     mean: -179.95652383493857
#     min: -489.5104128999022
#
# === ActorCriticTrainer LunarLander-v2 Iteration 7 ===
# Training Progress:
#   advantages_std: 0.9999998807907104
#   critic_loss: 102.37173461914062
#   evaluate_reward: -157.05575002439122
#   iter_episodes: 89
#   iter_time: 5.222777843475342
#   iter_timesteps: 10088
#   iteration: 7
#   mean_advantage: 5.4830602280731e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.3280506134033203
#   performance: -154.58548189581228
#   policy_loss: -277.85125732421875
#   total_episodes: 780
#   total_time: 47.591240882873535
#   total_timesteps: 80464
#   training_episode_length:
#     max: 197.0
#     mean: 113.34831460674157
#     min: 69.0
#   training_episode_reward:
#     max: -10.821038541925418
#     mean: -154.58548189581228
#     min: -456.462751819972
#
# === ActorCriticTrainer LunarLander-v2 Iteration 8 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 99.26318359375
#   evaluate_reward: -192.24089778054866
#   iter_episodes: 85
#   iter_time: 5.320126533508301
#   iter_timesteps: 10034
#   iteration: 8
#   mean_advantage: 5.227435373456046e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.311410903930664
#   performance: -184.07171726844234
#   policy_loss: -267.8120422363281
#   total_episodes: 865
#   total_time: 52.911367416381836
#   total_timesteps: 90498
#   training_episode_length:
#     max: 200.0
#     mean: 118.04705882352941
#     min: 70.0
#   training_episode_reward:
#     max: 1.5176058885280668
#     mean: -184.07171726844234
#     min: -655.8426220326406
#
# === ActorCriticTrainer LunarLander-v2 Iteration 9 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 92.69691467285156
#   evaluate_reward: -159.11866838386953
#   iter_episodes: 80
#   iter_time: 5.436589241027832
#   iter_timesteps: 10061
#   iteration: 9
#   mean_advantage: -1.042681385676758e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.2892568111419678
#   performance: -188.18176313808698
#   policy_loss: -258.7059631347656
#   total_episodes: 945
#   total_time: 58.34795665740967
#   total_timesteps: 100559
#   training_episode_length:
#     max: 220.0
#     mean: 125.7625
#     min: 73.0
#   training_episode_reward:
#     max: -10.718179873686395
#     mean: -188.18176313808698
#     min: -524.4788974694782
#
# === ActorCriticTrainer LunarLander-v2 Iteration 10 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 85.239501953125
#   evaluate_reward: -206.50695574849925
#   iter_episodes: 73
#   iter_time: 7.465512037277222
#   iter_timesteps: 10093
#   iteration: 10
#   mean_advantage: -6.519719430997384e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.2771790027618408
#   performance: -173.3907587785922
#   policy_loss: -251.05126953125
#   total_episodes: 1018
#   total_time: 65.81346869468689
#   total_timesteps: 110652
#   training_episode_length:
#     max: 229.0
#     mean: 138.26027397260273
#     min: 78.0
#   training_episode_reward:
#     max: 1.3838944463157787
#     mean: -173.3907587785922
#     min: -542.929093873791
#
# === ActorCriticTrainer LunarLander-v2 Iteration 11 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 81.45897674560547
#   evaluate_reward: -336.9209752170153
#   iter_episodes: 68
#   iter_time: 6.240895748138428
#   iter_timesteps: 10016
#   iteration: 11
#   mean_advantage: 1.9043017829289965e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.2353172302246094
#   performance: -260.7471283765056
#   policy_loss: 70.64795684814453
#   total_episodes: 1086
#   total_time: 72.05436444282532
#   total_timesteps: 120668
#   training_episode_length:
#     max: 246.0
#     mean: 147.2941176470588
#     min: 83.0
#   training_episode_reward:
#     max: 35.80518698403151
#     mean: -260.7471283765056
#     min: -580.4829597352011
#
# === ActorCriticTrainer LunarLander-v2 Iteration 12 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 83.84552764892578
#   evaluate_reward: -233.2796356551302
#   iter_episodes: 68
#   iter_time: 6.211694955825806
#   iter_timesteps: 10008
#   iteration: 12
#   mean_advantage: 8.480916413589057e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.22340989112854
#   performance: -252.95289773699534
#   policy_loss: -96.37968444824219
#   total_episodes: 1154
#   total_time: 78.26605939865112
#   total_timesteps: 130676
#   training_episode_length:
#     max: 279.0
#     mean: 147.1764705882353
#     min: 75.0
#   training_episode_reward:
#     max: 5.730068182182123
#     mean: -252.95289773699534
#     min: -865.3981006601343
#
# === ActorCriticTrainer LunarLander-v2 Iteration 13 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 81.17765808105469
#   evaluate_reward: -258.6777178118081
#   iter_episodes: 68
#   iter_time: 6.0031023025512695
#   iter_timesteps: 10028
#   iteration: 13
#   mean_advantage: 1.4550475491148518e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.2030582427978516
#   performance: -253.7053144293874
#   policy_loss: -117.83554077148438
#   total_episodes: 1222
#   total_time: 84.26916170120239
#   total_timesteps: 140704
#   training_episode_length:
#     max: 236.0
#     mean: 147.47058823529412
#     min: 88.0
#   training_episode_reward:
#     max: -6.11572469954389
#     mean: -253.7053144293874
#     min: -533.6505550339402
#
# === ActorCriticTrainer LunarLander-v2 Iteration 14 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 70.43641662597656
#   evaluate_reward: -210.08410010983053
#   iter_episodes: 58
#   iter_time: 7.10797905921936
#   iter_timesteps: 10119
#   iteration: 14
#   mean_advantage: -1.7341246660862453e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.1516112089157104
#   performance: -296.88897546679584
#   policy_loss: 179.07254028320312
#   total_episodes: 1280
#   total_time: 91.37714076042175
#   total_timesteps: 150823
#   training_episode_length:
#     max: 496.0
#     mean: 174.4655172413793
#     min: 87.0
#   training_episode_reward:
#     max: 2.4985661518491185
#     mean: -296.88897546679584
#     min: -1720.823927734233
#
# === ActorCriticTrainer LunarLander-v2 Iteration 15 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 72.84258270263672
#   evaluate_reward: -298.5079379974751
#   iter_episodes: 62
#   iter_time: 7.456933498382568
#   iter_timesteps: 10144
#   iteration: 15
#   mean_advantage: -4.3246273229158305e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1684552431106567
#   performance: -251.99086773202384
#   policy_loss: -37.06884765625
#   total_episodes: 1342
#   total_time: 98.83407425880432
#   total_timesteps: 160967
#   training_episode_length:
#     max: 623.0
#     mean: 163.61290322580646
#     min: 84.0
#   training_episode_reward:
#     max: 23.58150049872617
#     mean: -251.99086773202384
#     min: -632.0666252066885
#
# === ActorCriticTrainer LunarLander-v2 Iteration 16 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 71.63035583496094
#   evaluate_reward: -194.14931524079668
#   iter_episodes: 62
#   iter_time: 7.998161315917969
#   iter_timesteps: 10585
#   iteration: 16
#   mean_advantage: 5.9463869384046575e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1721701622009277
#   performance: -270.19307196117154
#   policy_loss: 127.01685333251953
#   total_episodes: 1404
#   total_time: 106.83223557472229
#   total_timesteps: 171552
#   training_episode_length:
#     max: 952.0
#     mean: 170.7258064516129
#     min: 92.0
#   training_episode_reward:
#     max: -27.517090037012906
#     mean: -270.19307196117154
#     min: -656.5972292767456
#
# === ActorCriticTrainer LunarLander-v2 Iteration 17 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 73.90464782714844
#   evaluate_reward: -234.25247417231836
#   iter_episodes: 61
#   iter_time: 6.666423082351685
#   iter_timesteps: 10065
#   iteration: 17
#   mean_advantage: 1.7055278300759369e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1657203435897827
#   performance: -258.0645142597517
#   policy_loss: -57.32905578613281
#   total_episodes: 1465
#   total_time: 113.49865865707397
#   total_timesteps: 181617
#   training_episode_length:
#     max: 361.0
#     mean: 165.0
#     min: 102.0
#   training_episode_reward:
#     max: -7.113678315187499
#     mean: -258.0645142597517
#     min: -849.8854050075812
#
# === ActorCriticTrainer LunarLander-v2 Iteration 18 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 72.82319641113281
#   evaluate_reward: -128.92937318056073
#   iter_episodes: 59
#   iter_time: 6.736765623092651
#   iter_timesteps: 10064
#   iteration: 18
#   mean_advantage: 1.042370523229863e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.155065655708313
#   performance: -228.1420124072584
#   policy_loss: -241.49301147460938
#   total_episodes: 1524
#   total_time: 120.23542428016663
#   total_timesteps: 191681
#   training_episode_length:
#     max: 888.0
#     mean: 170.57627118644066
#     min: 90.0
#   training_episode_reward:
#     max: 8.204161617204178
#     mean: -228.1420124072584
#     min: -641.8511911398738
#
# === ActorCriticTrainer LunarLander-v2 Iteration 19 ===
# Training Progress:
#   advantages_std: 1.0000001192092896
#   critic_loss: 69.18594360351562
#   evaluate_reward: -250.27777068490028
#   iter_episodes: 58
#   iter_time: 7.102355241775513
#   iter_timesteps: 10629
#   iteration: 19
#   mean_advantage: -3.3926812470497225e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.160179853439331
#   performance: -270.1914329256107
#   policy_loss: 1.8126951456069946
#   total_episodes: 1582
#   total_time: 127.33777952194214
#   total_timesteps: 202310
#   training_episode_length:
#     max: 1000.0
#     mean: 183.25862068965517
#     min: 94.0
#   training_episode_reward:
#     max: 1.661708937347484
#     mean: -270.1914329256107
#     min: -730.0835045220426
#
# === ActorCriticTrainer LunarLander-v2 Iteration 20 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 72.70868682861328
#   evaluate_reward: -238.2140101766955
#   iter_episodes: 59
#   iter_time: 7.261130094528198
#   iter_timesteps: 10150
#   iteration: 20
#   mean_advantage: 6.3891483215172684e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1397080421447754
#   performance: -241.51416483613602
#   policy_loss: -206.83116149902344
#   total_episodes: 1641
#   total_time: 134.59890961647034
#   total_timesteps: 212460
#   training_episode_length:
#     max: 1000.0
#     mean: 172.03389830508473
#     min: 88.0
#   training_episode_reward:
#     max: 23.342872105741495
#     mean: -241.51416483613602
#     min: -593.3360322334662
#
# === ActorCriticTrainer LunarLander-v2 Iteration 21 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 75.89022827148438
#   evaluate_reward: -188.04174453023015
#   iter_episodes: 63
#   iter_time: 5.843902111053467
#   iter_timesteps: 10011
#   iteration: 21
#   mean_advantage: 1.000257743299926e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.1339497566223145
#   performance: -223.9835361788133
#   policy_loss: -267.5670471191406
#   total_episodes: 1704
#   total_time: 140.4428117275238
#   total_timesteps: 222471
#   training_episode_length:
#     max: 261.0
#     mean: 158.9047619047619
#     min: 103.0
#   training_episode_reward:
#     max: 17.38423944211202
#     mean: -223.9835361788133
#     min: -501.42523522792004
#
# === ActorCriticTrainer LunarLander-v2 Iteration 22 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 70.03411102294922
#   evaluate_reward: -177.7249651612075
#   iter_episodes: 56
#   iter_time: 7.2265026569366455
#   iter_timesteps: 10068
#   iteration: 22
#   mean_advantage: -1.1461520621480759e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.1496630907058716
#   performance: -234.19370885374286
#   policy_loss: -356.8339538574219
#   total_episodes: 1760
#   total_time: 147.66931438446045
#   total_timesteps: 232539
#   training_episode_length:
#     max: 1000.0
#     mean: 179.78571428571428
#     min: 106.0
#   training_episode_reward:
#     max: 52.217774477077626
#     mean: -234.19370885374286
#     min: -602.4305583325797
#
# === ActorCriticTrainer LunarLander-v2 Iteration 23 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 73.18463897705078
#   evaluate_reward: -297.9774098245996
#   iter_episodes: 61
#   iter_time: 8.003626823425293
#   iter_timesteps: 10032
#   iteration: 23
#   mean_advantage: 1.0552018814280473e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.1261626482009888
#   performance: -223.39554839905864
#   policy_loss: -300.348876953125
#   total_episodes: 1821
#   total_time: 155.67294120788574
#   total_timesteps: 242571
#   training_episode_length:
#     max: 291.0
#     mean: 164.45901639344262
#     min: 101.0
#   training_episode_reward:
#     max: 15.390536739602155
#     mean: -223.39554839905864
#     min: -596.3373964884468
#
# === ActorCriticTrainer LunarLander-v2 Iteration 24 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 72.10462188720703
#   evaluate_reward: -177.41382005822462
#   iter_episodes: 58
#   iter_time: 7.4706785678863525
#   iter_timesteps: 10067
#   iteration: 24
#   mean_advantage: 3.0314470933490156e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1490973234176636
#   performance: -165.49294513100492
#   policy_loss: -329.6029052734375
#   total_episodes: 1879
#   total_time: 163.1436197757721
#   total_timesteps: 252638
#   training_episode_length:
#     max: 1000.0
#     mean: 173.56896551724137
#     min: 94.0
#   training_episode_reward:
#     max: 19.380919071831045
#     mean: -165.49294513100492
#     min: -392.672505561093
#
# === ActorCriticTrainer LunarLander-v2 Iteration 25 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 75.22462463378906
#   evaluate_reward: -302.3983103111662
#   iter_episodes: 62
#   iter_time: 6.9359447956085205
#   iter_timesteps: 10032
#   iteration: 25
#   mean_advantage: -1.6160749405358388e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.106099247932434
#   performance: -187.75916563717075
#   policy_loss: -370.745849609375
#   total_episodes: 1941
#   total_time: 170.07956457138062
#   total_timesteps: 262670
#   training_episode_length:
#     max: 260.0
#     mean: 161.80645161290323
#     min: 81.0
#   training_episode_reward:
#     max: 34.06368023974807
#     mean: -187.75916563717075
#     min: -495.61579543764145
#
# === ActorCriticTrainer LunarLander-v2 Iteration 26 ===
# Training Progress:
#   advantages_std: 0.9999998807907104
#   critic_loss: 65.2139892578125
#   evaluate_reward: -152.55397716397368
#   iter_episodes: 53
#   iter_time: 10.907632112503052
#   iter_timesteps: 10113
#   iteration: 26
#   mean_advantage: 2.734752868605028e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.1306328773498535
#   performance: -168.98830416586367
#   policy_loss: -487.3950500488281
#   total_episodes: 1994
#   total_time: 180.98719668388367
#   total_timesteps: 272783
#   training_episode_length:
#     max: 1000.0
#     mean: 190.81132075471697
#     min: 98.0
#   training_episode_reward:
#     max: 55.306825147879415
#     mean: -168.98830416586367
#     min: -392.16661162073405
#
# === ActorCriticTrainer LunarLander-v2 Iteration 27 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 74.5863037109375
#   evaluate_reward: -161.86036410074658
#   iter_episodes: 61
#   iter_time: 7.926774740219116
#   iter_timesteps: 10068
#   iteration: 27
#   mean_advantage: -6.251738682294672e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.0970995426177979
#   performance: -188.19845184759305
#   policy_loss: -384.11566162109375
#   total_episodes: 2055
#   total_time: 188.91397142410278
#   total_timesteps: 282851
#   training_episode_length:
#     max: 297.0
#     mean: 165.04918032786884
#     min: 93.0
#   training_episode_reward:
#     max: 47.618785846857946
#     mean: -188.19845184759305
#     min: -473.9435455130324
#
# === ActorCriticTrainer LunarLander-v2 Iteration 28 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 63.23719024658203
#   evaluate_reward: -145.2660604547666
#   iter_episodes: 51
#   iter_time: 8.178086519241333
#   iter_timesteps: 10279
#   iteration: 28
#   mean_advantage: 9.277890261616406e-11
#   mean_baselines: 1.0
#   mean_log_prob: -1.116896629333496
#   performance: -180.62303083845248
#   policy_loss: -457.8858337402344
#   total_episodes: 2106
#   total_time: 197.09205794334412
#   total_timesteps: 293130
#   training_episode_length:
#     max: 1000.0
#     mean: 201.54901960784315
#     min: 91.0
#   training_episode_reward:
#     max: 5.041288337351844
#     mean: -180.62303083845248
#     min: -440.72418236616267
#
# === ActorCriticTrainer LunarLander-v2 Iteration 29 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 70.15816497802734
#   evaluate_reward: -156.86962507273546
#   iter_episodes: 56
#   iter_time: 8.37891173362732
#   iter_timesteps: 10151
#   iteration: 29
#   mean_advantage: -2.7245152800503547e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.078567385673523
#   performance: -196.52061022066135
#   policy_loss: -440.6650695800781
#   total_episodes: 2162
#   total_time: 205.47096967697144
#   total_timesteps: 303281
#   training_episode_length:
#     max: 1000.0
#     mean: 181.26785714285714
#     min: 103.0
#   training_episode_reward:
#     max: 19.50972736766785
#     mean: -196.52061022066135
#     min: -397.04925901095675
#
# === ActorCriticTrainer LunarLander-v2 Iteration 30 ===
# Training Progress:
#   advantages_std: 1.0000001192092896
#   critic_loss: 73.8252944946289
#   evaluate_reward: -211.80322640560493
#   iter_episodes: 61
#   iter_time: 6.770256280899048
#   iter_timesteps: 10053
#   iteration: 30
#   mean_advantage: 1.3755373728940867e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.0517412424087524
#   performance: -159.66557073640286
#   policy_loss: -444.7134094238281
#   total_episodes: 2223
#   total_time: 212.24122595787048
#   total_timesteps: 313334
#   training_episode_length:
#     max: 331.0
#     mean: 164.80327868852459
#     min: 89.0
#   training_episode_reward:
#     max: 27.56664000304113
#     mean: -159.66557073640286
#     min: -473.0360227898121
#
# === ActorCriticTrainer LunarLander-v2 Iteration 31 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 65.6841812133789
#   evaluate_reward: -106.9086423237371
#   iter_episodes: 53
#   iter_time: 7.667623043060303
#   iter_timesteps: 10047
#   iteration: 31
#   mean_advantage: 1.5567094280299898e-08
#   mean_baselines: 1.0
#   mean_log_prob: -1.0514206886291504
#   performance: -169.58107878801314
#   policy_loss: -402.59454345703125
#   total_episodes: 2276
#   total_time: 219.9088490009308
#   total_timesteps: 323381
#   training_episode_length:
#     max: 1000.0
#     mean: 189.56603773584905
#     min: 87.0
#   training_episode_reward:
#     max: 19.390335904559436
#     mean: -169.58107878801314
#     min: -455.29267065117705
#
# === ActorCriticTrainer LunarLander-v2 Iteration 32 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 70.28046417236328
#   evaluate_reward: -220.2011489081255
#   iter_episodes: 56
#   iter_time: 7.21978235244751
#   iter_timesteps: 10094
#   iteration: 32
#   mean_advantage: 1.6061485474949677e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.0122153759002686
#   performance: -160.7238197900097
#   policy_loss: -388.2059326171875
#   total_episodes: 2332
#   total_time: 227.1286313533783
#   total_timesteps: 333475
#   training_episode_length:
#     max: 508.0
#     mean: 180.25
#     min: 94.0
#   training_episode_reward:
#     max: 41.020589504891944
#     mean: -160.7238197900097
#     min: -393.0225576042884
#
# === ActorCriticTrainer LunarLander-v2 Iteration 33 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 53.61492919921875
#   evaluate_reward: -56.71068789170622
#   iter_episodes: 40
#   iter_time: 10.67757773399353
#   iter_timesteps: 10011
#   iteration: 33
#   mean_advantage: -1.8099901577528499e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.0573152303695679
#   performance: -193.03330448483848
#   policy_loss: -311.547607421875
#   total_episodes: 2372
#   total_time: 237.80620908737183
#   total_timesteps: 343486
#   training_episode_length:
#     max: 1000.0
#     mean: 250.275
#     min: 107.0
#   training_episode_reward:
#     max: 16.70058434120726
#     mean: -193.03330448483848
#     min: -400.9290464583404
#
# === ActorCriticTrainer LunarLander-v2 Iteration 34 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 59.5904426574707
#   evaluate_reward: -128.30900340022976
#   iter_episodes: 45
#   iter_time: 10.771270990371704
#   iter_timesteps: 10065
#   iteration: 34
#   mean_advantage: -3.4110556601518738e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.0073539018630981
#   performance: -167.26948236454243
#   policy_loss: -329.7538146972656
#   total_episodes: 2417
#   total_time: 248.57748007774353
#   total_timesteps: 353551
#   training_episode_length:
#     max: 1000.0
#     mean: 223.66666666666666
#     min: 113.0
#   training_episode_reward:
#     max: 38.32919661249155
#     mean: -167.26948236454243
#     min: -403.6712565571623
#
# === ActorCriticTrainer LunarLander-v2 Iteration 35 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 60.96814727783203
#   evaluate_reward: -210.05208256038577
#   iter_episodes: 49
#   iter_time: 8.45317792892456
#   iter_timesteps: 10110
#   iteration: 35
#   mean_advantage: 1.424380080550236e-08
#   mean_baselines: 1.0
#   mean_log_prob: -0.9749786257743835
#   performance: -186.89645594041164
#   policy_loss: -401.7395935058594
#   total_episodes: 2466
#   total_time: 257.0306580066681
#   total_timesteps: 363661
#   training_episode_length:
#     max: 1000.0
#     mean: 206.3265306122449
#     min: 98.0
#   training_episode_reward:
#     max: 48.68398624971934
#     mean: -186.89645594041164
#     min: -432.2288249335444
#
# === ActorCriticTrainer LunarLander-v2 Iteration 36 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 62.32473373413086
#   evaluate_reward: -217.49177089176337
#   iter_episodes: 50
#   iter_time: 10.598560571670532
#   iter_timesteps: 10500
#   iteration: 36
#   mean_advantage: -8.743433532742984e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9874475598335266
#   performance: -161.20069944352687
#   policy_loss: -189.66030883789062
#   total_episodes: 2516
#   total_time: 267.6292185783386
#   total_timesteps: 374161
#   training_episode_length:
#     max: 1000.0
#     mean: 210.0
#     min: 90.0
#   training_episode_reward:
#     max: 52.302213358778914
#     mean: -161.20069944352687
#     min: -566.9051831754803
#
# === ActorCriticTrainer LunarLander-v2 Iteration 37 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 52.433563232421875
#   evaluate_reward: -158.15973467381656
#   iter_episodes: 40
#   iter_time: 11.378942251205444
#   iter_timesteps: 10064
#   iteration: 37
#   mean_advantage: -7.580877037227651e-10
#   mean_baselines: 1.0
#   mean_log_prob: -0.9946848154067993
#   performance: -170.4865393112958
#   policy_loss: -361.13995361328125
#   total_episodes: 2556
#   total_time: 279.00816082954407
#   total_timesteps: 384225
#   training_episode_length:
#     max: 1000.0
#     mean: 251.6
#     min: 95.0
#   training_episode_reward:
#     max: 14.377807661768088
#     mean: -170.4865393112958
#     min: -377.71872759069373
#
# === ActorCriticTrainer LunarLander-v2 Iteration 38 ===
# Training Progress:
#   advantages_std: 0.9999998807907104
#   critic_loss: 59.61888885498047
#   evaluate_reward: -180.77215892499513
#   iter_episodes: 48
#   iter_time: 9.07111144065857
#   iter_timesteps: 10016
#   iteration: 38
#   mean_advantage: 3.951426297277294e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9672044515609741
#   performance: -145.2355808525414
#   policy_loss: -528.160888671875
#   total_episodes: 2604
#   total_time: 288.07927227020264
#   total_timesteps: 394241
#   training_episode_length:
#     max: 1000.0
#     mean: 208.66666666666666
#     min: 96.0
#   training_episode_reward:
#     max: 25.271988567232405
#     mean: -145.2355808525414
#     min: -407.2840466485424
#
# === ActorCriticTrainer LunarLander-v2 Iteration 39 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 62.46683120727539
#   evaluate_reward: -173.4111277044305
#   iter_episodes: 49
#   iter_time: 9.157511234283447
#   iter_timesteps: 10293
#   iteration: 39
#   mean_advantage: 1.3347780658534703e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9554427266120911
#   performance: -141.21347127315042
#   policy_loss: -369.17510986328125
#   total_episodes: 2653
#   total_time: 297.2367835044861
#   total_timesteps: 404534
#   training_episode_length:
#     max: 1000.0
#     mean: 210.0612244897959
#     min: 99.0
#   training_episode_reward:
#     max: 23.64487849775901
#     mean: -141.21347127315042
#     min: -316.2003001655637
#
# === ActorCriticTrainer LunarLander-v2 Iteration 40 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 44.11125946044922
#   evaluate_reward: -96.26783890608908
#   iter_episodes: 31
#   iter_time: 13.231592655181885
#   iter_timesteps: 10045
#   iteration: 40
#   mean_advantage: -2.1836246144602e-09
#   mean_baselines: 1.0
#   mean_log_prob: -1.033973217010498
#   performance: -119.85879561742401
#   policy_loss: -448.4310607910156
#   total_episodes: 2684
#   total_time: 310.46837615966797
#   total_timesteps: 414579
#   training_episode_length:
#     max: 1000.0
#     mean: 324.03225806451616
#     min: 103.0
#   training_episode_reward:
#     max: 15.124744628054795
#     mean: -119.85879561742401
#     min: -339.6386345906626
#
# === ActorCriticTrainer LunarLander-v2 Iteration 41 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 57.206539154052734
#   evaluate_reward: -139.1286490383614
#   iter_episodes: 45
#   iter_time: 11.059755325317383
#   iter_timesteps: 10119
#   iteration: 41
#   mean_advantage: -8.105147664139167e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9471144080162048
#   performance: -127.40028893113269
#   policy_loss: -323.58905029296875
#   total_episodes: 2729
#   total_time: 321.52813148498535
#   total_timesteps: 424698
#   training_episode_length:
#     max: 1000.0
#     mean: 224.86666666666667
#     min: 107.0
#   training_episode_reward:
#     max: 50.46536738875543
#     mean: -127.40028893113269
#     min: -279.86354166739966
#
# === ActorCriticTrainer LunarLander-v2 Iteration 42 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 42.32395935058594
#   evaluate_reward: -191.4995530573864
#   iter_episodes: 30
#   iter_time: 11.255011796951294
#   iter_timesteps: 10076
#   iteration: 42
#   mean_advantage: 5.475540909571919e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9965492486953735
#   performance: -121.83161551169695
#   policy_loss: -223.78919982910156
#   total_episodes: 2759
#   total_time: 332.78314328193665
#   total_timesteps: 434774
#   training_episode_length:
#     max: 1000.0
#     mean: 335.8666666666667
#     min: 94.0
#   training_episode_reward:
#     max: 23.722933053691516
#     mean: -121.83161551169695
#     min: -310.0401450291882
#
# === ActorCriticTrainer LunarLander-v2 Iteration 43 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 58.27470016479492
#   evaluate_reward: -231.8674219072255
#   iter_episodes: 45
#   iter_time: 8.57019853591919
#   iter_timesteps: 10146
#   iteration: 43
#   mean_advantage: -1.785906977858076e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.8876201510429382
#   performance: -151.85324629823694
#   policy_loss: -451.9705810546875
#   total_episodes: 2804
#   total_time: 341.35334181785583
#   total_timesteps: 444920
#   training_episode_length:
#     max: 1000.0
#     mean: 225.46666666666667
#     min: 105.0
#   training_episode_reward:
#     max: 68.08202828030807
#     mean: -151.85324629823694
#     min: -388.8260151672921
#
# === ActorCriticTrainer LunarLander-v2 Iteration 44 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 58.14671325683594
#   evaluate_reward: -149.5291614430518
#   iter_episodes: 45
#   iter_time: 10.281399965286255
#   iter_timesteps: 10182
#   iteration: 44
#   mean_advantage: -5.619766318964992e-10
#   mean_baselines: 1.0
#   mean_log_prob: -0.8834182024002075
#   performance: -134.69470127666477
#   policy_loss: -401.03021240234375
#   total_episodes: 2849
#   total_time: 351.6347417831421
#   total_timesteps: 455102
#   training_episode_length:
#     max: 1000.0
#     mean: 226.26666666666668
#     min: 101.0
#   training_episode_reward:
#     max: 84.94401911899885
#     mean: -134.69470127666477
#     min: -385.30867197289575
#
# === ActorCriticTrainer LunarLander-v2 Iteration 45 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 49.8288459777832
#   evaluate_reward: -91.05432302374206
#   iter_episodes: 38
#   iter_time: 9.800212621688843
#   iter_timesteps: 10003
#   iteration: 45
#   mean_advantage: -1.1440659974937262e-08
#   mean_baselines: 1.0
#   mean_log_prob: -0.9204185009002686
#   performance: -138.07768555624708
#   policy_loss: -384.6564636230469
#   total_episodes: 2887
#   total_time: 361.43495440483093
#   total_timesteps: 465105
#   training_episode_length:
#     max: 1000.0
#     mean: 263.2368421052632
#     min: 120.0
#   training_episode_reward:
#     max: 72.53082337761845
#     mean: -138.07768555624708
#     min: -302.0676352047409
#
# === ActorCriticTrainer LunarLander-v2 Iteration 46 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 54.88970184326172
#   evaluate_reward: -174.16537918885317
#   iter_episodes: 43
#   iter_time: 11.797061204910278
#   iter_timesteps: 10485
#   iteration: 46
#   mean_advantage: 5.4104645208497004e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.8694040179252625
#   performance: -138.85369281125713
#   policy_loss: -361.3035888671875
#   total_episodes: 2930
#   total_time: 373.2320156097412
#   total_timesteps: 475590
#   training_episode_length:
#     max: 1000.0
#     mean: 243.8372093023256
#     min: 102.0
#   training_episode_reward:
#     max: 8.174174867763114
#     mean: -138.85369281125713
#     min: -371.3403627799887
#
# === ActorCriticTrainer LunarLander-v2 Iteration 47 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 45.634521484375
#   evaluate_reward: -152.71716412876194
#   iter_episodes: 31
#   iter_time: 12.523848056793213
#   iter_timesteps: 10496
#   iteration: 47
#   mean_advantage: -8.17746670378483e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9385969638824463
#   performance: -145.9741165283568
#   policy_loss: -265.49627685546875
#   total_episodes: 2961
#   total_time: 385.7558636665344
#   total_timesteps: 486086
#   training_episode_length:
#     max: 1000.0
#     mean: 338.5806451612903
#     min: 103.0
#   training_episode_reward:
#     max: 44.04716616876854
#     mean: -145.9741165283568
#     min: -332.3094122206445
#
# === ActorCriticTrainer LunarLander-v2 Iteration 48 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 45.46440505981445
#   evaluate_reward: -169.0636428563361
#   iter_episodes: 34
#   iter_time: 11.725342035293579
#   iter_timesteps: 10124
#   iteration: 48
#   mean_advantage: -2.825980838228048e-10
#   mean_baselines: 1.0
#   mean_log_prob: -0.9083296060562134
#   performance: -92.41440722357449
#   policy_loss: -444.4474182128906
#   total_episodes: 2995
#   total_time: 397.481205701828
#   total_timesteps: 496210
#   training_episode_length:
#     max: 1000.0
#     mean: 297.7647058823529
#     min: 133.0
#   training_episode_reward:
#     max: 80.20821464409121
#     mean: -92.41440722357449
#     min: -292.5564079369441
#
# === ActorCriticTrainer LunarLander-v2 Iteration 49 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 58.331172943115234
#   evaluate_reward: -200.66440404094652
#   iter_episodes: 45
#   iter_time: 9.537133693695068
#   iter_timesteps: 10194
#   iteration: 49
#   mean_advantage: 8.419726249542236e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7994589805603027
#   performance: -151.83534400802762
#   policy_loss: -426.6600341796875
#   total_episodes: 3040
#   total_time: 407.01833939552307
#   total_timesteps: 506404
#   training_episode_length:
#     max: 423.0
#     mean: 226.53333333333333
#     min: 108.0
#   training_episode_reward:
#     max: 55.601442321413
#     mean: -151.83534400802762
#     min: -342.0076686356245
#
# === ActorCriticTrainer LunarLander-v2 Iteration 50 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 49.87031936645508
#   evaluate_reward: -177.08654502707518
#   iter_episodes: 37
#   iter_time: 11.272287368774414
#   iter_timesteps: 10042
#   iteration: 50
#   mean_advantage: 7.027673554205194e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.8444532155990601
#   performance: -158.92925213893386
#   policy_loss: -142.43760681152344
#   total_episodes: 3077
#   total_time: 418.2906267642975
#   total_timesteps: 516446
#   training_episode_length:
#     max: 1000.0
#     mean: 271.4054054054054
#     min: 96.0
#   training_episode_reward:
#     max: 16.578060022333318
#     mean: -158.92925213893386
#     min: -300.8081365258196
#
# === ActorCriticTrainer LunarLander-v2 Iteration 51 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 57.591365814208984
#   evaluate_reward: -170.73015150596274
#   iter_episodes: 49
#   iter_time: 8.574244976043701
#   iter_timesteps: 10999
#   iteration: 51
#   mean_advantage: -3.923426028507038e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.8008550405502319
#   performance: -130.11156900825023
#   policy_loss: -438.3977355957031
#   total_episodes: 3126
#   total_time: 426.8648717403412
#   total_timesteps: 527445
#   training_episode_length:
#     max: 1000.0
#     mean: 224.46938775510205
#     min: 107.0
#   training_episode_reward:
#     max: 67.67732332676121
#     mean: -130.11156900825023
#     min: -270.4910488047574
#
# === ActorCriticTrainer LunarLander-v2 Iteration 52 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 41.957801818847656
#   evaluate_reward: -143.26218719456364
#   iter_episodes: 31
#   iter_time: 12.43070912361145
#   iter_timesteps: 10725
#   iteration: 52
#   mean_advantage: -1.31158006677623e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.9338874816894531
#   performance: -115.19271440424781
#   policy_loss: -261.1141357421875
#   total_episodes: 3157
#   total_time: 439.29558086395264
#   total_timesteps: 538170
#   training_episode_length:
#     max: 1000.0
#     mean: 345.96774193548384
#     min: 100.0
#   training_episode_reward:
#     max: 62.801420849977745
#     mean: -115.19271440424781
#     min: -270.2912849030414
#
# === ActorCriticTrainer LunarLander-v2 Iteration 53 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 41.98387145996094
#   evaluate_reward: -143.25042418821272
#   iter_episodes: 33
#   iter_time: 12.333354473114014
#   iter_timesteps: 10985
#   iteration: 53
#   mean_advantage: 3.619313737601715e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.905868649482727
#   performance: -114.09007207451455
#   policy_loss: -409.4341735839844
#   total_episodes: 3190
#   total_time: 451.62893533706665
#   total_timesteps: 549155
#   training_episode_length:
#     max: 1000.0
#     mean: 332.8787878787879
#     min: 111.0
#   training_episode_reward:
#     max: 20.45147965394733
#     mean: -114.09007207451455
#     min: -285.9509392642873
#
# === ActorCriticTrainer LunarLander-v2 Iteration 54 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 55.132938385009766
#   evaluate_reward: -161.19629346224588
#   iter_episodes: 42
#   iter_time: 8.182427883148193
#   iter_timesteps: 10106
#   iteration: 54
#   mean_advantage: 1.5098742256469677e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7882556915283203
#   performance: -125.22876968383132
#   policy_loss: -371.9348449707031
#   total_episodes: 3232
#   total_time: 459.81136322021484
#   total_timesteps: 559261
#   training_episode_length:
#     max: 1000.0
#     mean: 240.61904761904762
#     min: 117.0
#   training_episode_reward:
#     max: 75.80864237760159
#     mean: -125.22876968383132
#     min: -320.41525109406757
#
# === ActorCriticTrainer LunarLander-v2 Iteration 55 ===
# Training Progress:
#   advantages_std: 1.0000001192092896
#   critic_loss: 44.1533088684082
#   evaluate_reward: -112.13242542478534
#   iter_episodes: 32
#   iter_time: 10.876585960388184
#   iter_timesteps: 10025
#   iteration: 55
#   mean_advantage: 9.60809032335419e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.852857768535614
#   performance: -119.65954427075516
#   policy_loss: -454.4639892578125
#   total_episodes: 3264
#   total_time: 470.687949180603
#   total_timesteps: 569286
#   training_episode_length:
#     max: 1000.0
#     mean: 313.28125
#     min: 117.0
#   training_episode_reward:
#     max: 56.65414825652599
#     mean: -119.65954427075516
#     min: -343.8533734862244
#
# === ActorCriticTrainer LunarLander-v2 Iteration 56 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 47.49319076538086
#   evaluate_reward: -61.41929532656616
#   iter_episodes: 35
#   iter_time: 11.154213428497314
#   iter_timesteps: 10145
#   iteration: 56
#   mean_advantage: -6.956323073126214e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.8291807174682617
#   performance: -117.46436608642922
#   policy_loss: -282.8536071777344
#   total_episodes: 3299
#   total_time: 481.84216260910034
#   total_timesteps: 579431
#   training_episode_length:
#     max: 1000.0
#     mean: 289.85714285714283
#     min: 111.0
#   training_episode_reward:
#     max: 24.028671657846203
#     mean: -117.46436608642922
#     min: -320.2619907390123
#
# === ActorCriticTrainer LunarLander-v2 Iteration 57 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 60.191444396972656
#   evaluate_reward: -89.24642310126575
#   iter_episodes: 46
#   iter_time: 7.98190975189209
#   iter_timesteps: 10181
#   iteration: 57
#   mean_advantage: -2.7164870353146853e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7196142077445984
#   performance: -143.23638414011296
#   policy_loss: -300.5969543457031
#   total_episodes: 3345
#   total_time: 489.82407236099243
#   total_timesteps: 589612
#   training_episode_length:
#     max: 421.0
#     mean: 221.32608695652175
#     min: 106.0
#   training_episode_reward:
#     max: 19.199596876031833
#     mean: -143.23638414011296
#     min: -306.1379880029194
#
# === ActorCriticTrainer LunarLander-v2 Iteration 58 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 56.421714782714844
#   evaluate_reward: -110.22195338564559
#   iter_episodes: 43
#   iter_time: 8.647743940353394
#   iter_timesteps: 10080
#   iteration: 58
#   mean_advantage: 3.0275375539901006e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7289501428604126
#   performance: -144.85849077956988
#   policy_loss: -175.4830780029297
#   total_episodes: 3388
#   total_time: 498.4718163013458
#   total_timesteps: 599692
#   training_episode_length:
#     max: 615.0
#     mean: 234.41860465116278
#     min: 128.0
#   training_episode_reward:
#     max: 39.993475255316866
#     mean: -144.85849077956988
#     min: -252.14943801435604
#
# === ActorCriticTrainer LunarLander-v2 Iteration 59 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 42.87639236450195
#   evaluate_reward: -145.4605563818631
#   iter_episodes: 33
#   iter_time: 12.076704025268555
#   iter_timesteps: 10176
#   iteration: 59
#   mean_advantage: 1.274564720432636e-08
#   mean_baselines: 1.0
#   mean_log_prob: -0.8231671452522278
#   performance: -128.89619986405944
#   policy_loss: -301.4591369628906
#   total_episodes: 3421
#   total_time: 510.5485203266144
#   total_timesteps: 609868
#   training_episode_length:
#     max: 1000.0
#     mean: 308.3636363636364
#     min: 131.0
#   training_episode_reward:
#     max: 22.901163958541257
#     mean: -128.89619986405944
#     min: -330.6927499168869
#
# === ActorCriticTrainer LunarLander-v2 Iteration 60 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 42.866943359375
#   evaluate_reward: -102.50479051222689
#   iter_episodes: 32
#   iter_time: 12.265031576156616
#   iter_timesteps: 10298
#   iteration: 60
#   mean_advantage: 3.067630871544935e-10
#   mean_baselines: 1.0
#   mean_log_prob: -0.8292182087898254
#   performance: -99.22697862178052
#   policy_loss: -451.0321960449219
#   total_episodes: 3453
#   total_time: 522.813551902771
#   total_timesteps: 620166
#   training_episode_length:
#     max: 1000.0
#     mean: 321.8125
#     min: 93.0
#   training_episode_reward:
#     max: 52.288097263972816
#     mean: -99.22697862178052
#     min: -260.20132610007965
#
# === ActorCriticTrainer LunarLander-v2 Iteration 61 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 43.707096099853516
#   evaluate_reward: -205.4065628572842
#   iter_episodes: 32
#   iter_time: 13.587397813796997
#   iter_timesteps: 10075
#   iteration: 61
#   mean_advantage: -1.4009310156382071e-08
#   mean_baselines: 1.0
#   mean_log_prob: -0.7914295792579651
#   performance: -163.40166374233712
#   policy_loss: -196.30496215820312
#   total_episodes: 3485
#   total_time: 536.400949716568
#   total_timesteps: 630241
#   training_episode_length:
#     max: 1000.0
#     mean: 314.84375
#     min: 106.0
#   training_episode_reward:
#     max: 62.777450093005854
#     mean: -163.40166374233712
#     min: -292.3625423757087
#
# === ActorCriticTrainer LunarLander-v2 Iteration 62 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 50.31610870361328
#   evaluate_reward: -151.2625868336743
#   iter_episodes: 38
#   iter_time: 9.613611459732056
#   iter_timesteps: 10018
#   iteration: 62
#   mean_advantage: -2.5702941996996742e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7547774314880371
#   performance: -111.00948746993495
#   policy_loss: -269.8402099609375
#   total_episodes: 3523
#   total_time: 546.0145611763
#   total_timesteps: 640259
#   training_episode_length:
#     max: 1000.0
#     mean: 263.63157894736844
#     min: 116.0
#   training_episode_reward:
#     max: 56.42396613034671
#     mean: -111.00948746993495
#     min: -304.4896118783628
#
# === ActorCriticTrainer LunarLander-v2 Iteration 63 ===
# Training Progress:
#   advantages_std: 0.9999999403953552
#   critic_loss: 57.509647369384766
#   evaluate_reward: -100.07430452432997
#   iter_episodes: 48
#   iter_time: 9.484001398086548
#   iter_timesteps: 10685
#   iteration: 63
#   mean_advantage: 8.919777805260765e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7086832523345947
#   performance: -132.65870503216948
#   policy_loss: -375.1048278808594
#   total_episodes: 3571
#   total_time: 555.4985625743866
#   total_timesteps: 650944
#   training_episode_length:
#     max: 1000.0
#     mean: 222.60416666666666
#     min: 112.0
#   training_episode_reward:
#     max: 41.06651593575527
#     mean: -132.65870503216948
#     min: -268.2209410317632
#
# === ActorCriticTrainer LunarLander-v2 Iteration 64 ===
# Training Progress:
#   advantages_std: 1.0
#   critic_loss: 49.784934997558594
#   evaluate_reward: -102.74079344749478
#   iter_episodes: 38
#   iter_time: 12.634170532226562
#   iter_timesteps: 10201
#   iteration: 64
#   mean_advantage: 3.955724192650223e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7743449807167053
#   performance: -125.38803874636237
#   policy_loss: -298.1756896972656
#   total_episodes: 3609
#   total_time: 568.1327331066132
#   total_timesteps: 661145
#   training_episode_length:
#     max: 1000.0
#     mean: 268.44736842105266
#     min: 117.0
#   training_episode_reward:
#     max: 59.90442248378009
#     mean: -125.38803874636237
#     min: -266.74558057777915
#
# === ActorCriticTrainer LunarLander-v2 Iteration 65 ===
# Training Progress:
#   advantages_std: 1.0000001192092896
#   critic_loss: 53.853187561035156
#   evaluate_reward: -100.38209903295109
#   iter_episodes: 42
#   iter_time: 10.861103773117065
#   iter_timesteps: 10140
#   iteration: 65
#   mean_advantage: -9.781275345233098e-09
#   mean_baselines: 1.0
#   mean_log_prob: -0.7075229287147522
#   performance: -108.60831120568346
#   policy_loss: -458.3909606933594
#   total_episodes: 3651
#   total_time: 578.9938368797302
#   total_timesteps: 671285
#   training_episode_length:
#     max: 1000.0
#     mean: 241.42857142857142
#     min: 141.0
#   training_episode_reward:
#     max: 44.426986786039095
#     mean: -108.60831120568346
#     min: -267.46154286884
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-9cee895f3e16> in <module>
#      10     evaluate_interval=1,
#      11     evaluate_num_episodes=5,
# ---> 12 ), 200)
#      13
#      14 # Hint: 1. This would take hours to train on personal laptop.
#
# <ipython-input-4-3dae9e2e052d> in run(trainer_cls, config, reward_threshold)
#      22         if i % config['evaluate_interval'] == 0 or \
#      23                 i == config["max_iteration"]:
# ---> 24             reward = trainer.evaluate(config["evaluate_num_episodes"])
#      25             stat["evaluate_reward"] = reward
#      26             print("=== {} {} Iteration {} ===".format(
#
# <ipython-input-5-c6fca0ec0831> in evaluate(self, num_episodes, render)
#      60     def evaluate(self, num_episodes=10, render=False):
#      61         """Evaluate the agents for num_episodes episodes."""
# ---> 62         return evaluate_agent(self, self.env, num_episodes, render)
#      63
#      64     def to_tensor(self, array):
#
# ~\Desktop\毕设\code\ierg6130-assignment\assignment3\utils.py in evaluate_agent(pg_agent, env, num_episodes, render)
#      69
#      70             # Query the agent to get action
# ---> 71             act = pg_agent.compute_action(obs)
#      72
#      73             ep_reward += reward
#
# <ipython-input-110-32501d8be614> in compute_action(self, observation)
#      49         #  expand the first dimension of observation before feeding it to policy network.
#      50         action = None
# ---> 51         observation = self.to_tensor(observation)
#      52         observation = observation.view(1,-1)
#      53         action = self.policy(observation)
#
# <ipython-input-110-32501d8be614> in to_tensor(self, array)
#      36     def to_tensor(self, array):
#      37         """Transform a numpy array to a pytorch tensor"""
# ---> 38         return torch.from_numpy(array).to(self.device)
#      39
#      40     def to_array(self, tensor):
#
# KeyboardInterrupt:

# %%
# Run this cell without modification

# Plot the result to diagnose potential problem.
sns.lineplot(
    x="total_timesteps", y="performance", data=ac_result_lander
).set_title("Episode Reward in LunarLander-v2")

# %%
# Run this cell without modification

# You should see a pop up window which display the movement of the cart and pole.
print("Average episode reward for your Actor-critic agent in LunarLander-v2: ",
      ac_trainer_lander.evaluate(1, render=True))
print("One small step for agent, one giant leap for mankind.")

# %% [markdown]
# ### Section 4.3: Even harder -- train Pong agents
#
# (5 / 100 points)

# %%
# Run this cell without modification
e = gym.make("PongDeterministic-v4"); e.reset()
frames = []
for _ in range(1000):
    frames.append(e.render("rgb_array"))
    if e.step(e.action_space.sample())[2]: break
e.close();animate(frames);del e

# %% [markdown]
# In this section, we will train agents to play Pong game in Atari environment. The agent control the bat on the right with up or down action to make it hit the table tennis ball to left side. The agent need to beat a rule-based AI.
#
# The observation of the environment `PongDeterministic-v4` is an image of 210 X 160 X 3 pixels. We compress the image and flatten it to be a vector with 6400 elements. To do this, we provide you a wrapper class which wrap the actor-critic trainer to fit this environment. You need to implement the save and restore functions.
#
# In the assignment 4, we will trained state of the art Pong agents with various algorithms. Your agents will battle with other AI. Let's get familiar with Pong by finishing this section!

# %%
# Run this cell without modification

def process_img(img):
    """In this function, we process the raw image array into a flat vector.
    We assume the img has four dimension, with shape in [Batch size, Width, Height, Channel].
    Therefore the raw image is a 4D matrix containing the intensity of colors.
    """
    assert img.shape[-3:] == (210, 160, 3), img.shape
    
    # Add extra axis if input is a single image and make it looks like a batch.
    single_img = False
    if img.ndim == 3:
        img = img[None, ...]
        single_img = True
        
    # Crop the image
    img = img[:, 35:195]
    
    # Shrink the image size by taking only 1/4 of the pixel
    img = img[:, ::2, ::2, 0]
    
    # Erase background
    img[img == 144] = 0
    img[img == 109] = 0
    
    # Paint everything (paddles, ball) to 1
    img[img != 0 ] = 1
    
    # Flatten image to vector
    img = img.astype(np.float).reshape(-1, 6400)
    
    # Reverse single image
    if single_img:
        img = img[0, ...]
    return img

# %%
# Solve the TODOs and remove `pass`

def pong_wrapper(trainer):
    assert inspect.isclass(trainer)
    
    class WrappedTrainer(trainer):
        def __init__(self, *a, **k):
            super().__init__(*a, **k)
            self.obs_dim = 6400
            self.build_model()
            assert "Pong" in self.config["env_name"]
            
        def compute_action(self, obs):
            obs = process_img(obs)
            return super().compute_action(obs)
            
        def process_samples(self, samples):
            samples["obs"] = [process_img(traj_obs) for traj_obs in samples["obs"]]
            return super().process_samples(samples)
        
        def train(self):
            ret = super().train()
            if self.iteration % self.config["evaluate_interval"] == 0:
                self.save("iter{}".format(self.iteration))
                print("Finished {} iterations training. "
                      "Checkpoint is saved in checkpoints directory.".format(self.iteration))
            return ret
        
        def save(self, surfix="checkpoint"):
            import pickle
            import os
            os.makedirs("checkpoints", exist_ok=True)
            policy_file_name = "checkpoints/pong-agent-{}-policy.pkl".format(surfix)
            with open(policy_file_name, "wb") as f:
                # [TODO] Use function of pickle package and torch model to save 
                # the parameters of self.policy to file "f".
                # Hint: a function called state_dict of torch model may help.
                pass
            
            baseline_file_name = "checkpoints/pong-agent-{}-baseline.pkl".format(surfix)
            with open(baseline_file_name, "wb") as f:
                # [TODO] Use function of pickle package and torch model to save 
                # the parameters of self.baseline to file "f".
                pass
                    
        def restore(self, surfix="checkpoint"):
            import pickle
            policy_file_name = "checkpoints/pong-agent-{}-policy.pkl".format(surfix)
            with open(policy_file_name, "rb") as f:
                # [TODO] Use function of pickle package and torch model to restore 
                # the parameters of self.policy from file "f".
                # Hint: a function called load_state_dict of torch model may help.
                pass
                
            baseline_file_name = "checkpoints/pong-agent-{}-baseline.pkl".format(surfix)
            with open(baseline_file_name, "rb") as f:
                # [TODO] Use function of pickle package and torch model to restore 
                # the parameters of self.baseline from file "f".
                pass
        
    return WrappedTrainer


# Test save and restore
pong_wrapper(ActorCriticTrainer)({"env_name": "Pong-v0"}).save("test")
pong_wrapper(ActorCriticTrainer)({"env_name": "Pong-v0"}).restore("test")
import os
os.remove("checkpoints/pong-agent-test-baseline.pkl")
os.remove("checkpoints/pong-agent-test-policy.pkl")
print("Test passed!")

# %%
# Run this cell without modification

pong_ac_config = dict(
    # environment
    env_name="PongDeterministic-v4",

    # model
    hidden_units=100,

    # training inner loop
    learning_rate=0.0005,

    # training outer loop
    max_iteration=200,
    max_episode_length=5000,  # In fact the game end at 10000 steps
    train_batch_size=5000,

    # evaluation
    evaluate_interval=10,
    evaluate_num_episodes=10
)

ac_trainer_pong, ac_result_pong = run(pong_wrapper(ActorCriticTrainer), pong_ac_config, 18.0)

# Hint: Performance should greater than -20.0 within one hour.
# We do not require you to solve the task, but you need to make your agent achieve > -20 reward.

# %%
surfix = "iter130"

ac_trainer_pong_restored = pong_wrapper(ActorCriticTrainer)(pong_ac_config)
ac_trainer_pong_restored.restore(surfix)

print("Average episode reward for your Actor-critic agent in PongDeterministic-v4: ",
      ac_trainer_pong_restored.evaluate(1, render=True))

# %% [markdown]
# ------
#
# ## Conclusion and Discussion
#
# In this assignment, we implement several policy gradient algorithms.
#
# It's OK to leave the following cells empty. In the next markdown cell, you can write whatever you like. Like the suggestion on the course, the confusing problems in the assignments, and so on.
#
# If you want to do more investigation, feel free to open new cells via `Esc + B` after the next cells and write codes in it, so that you can reuse some result in this notebook. Remember to write sufficient comments and documents to let others know what you are doing.
#
# Following the submission instruction in the assignment to submit your assignment to our staff. Thank you!
#
# ------
